# %% [markdown]
# **Importiere die notwendigen Packages**

# %%
# Empfehlung für Colab: Installiere alles was Du brauchst
# %pip install pandas pivottablejs numpy altair matplotlib geopandas folium

# %%
import pandas as pd
import pivottablejs
from pivottablejs import pivot_ui
import numpy as np
import altair as alt
import matplotlib.pyplot as plt
from datetime import datetime
import geopandas as gpd
import folium

# %% [markdown]
# Definiere Settings. Hier das Zahlenformat von Float-Werten (z.B. *'{:,.2f}'.format* mit Komma als Tausenderzeichen),

# %%
pd.options.display.float_format = '{:.0f}'.format
pd.set_option('display.width', 100)
pd.set_option('display.max_columns', 15)

# %% [markdown]
# Importiere einen Datensatz von der **DWH_INT** Dropzone.
#
# - Beachte dabei die Notation des Pfades...
# - Definiere mal aktuell noch keine weiteren Parameter beim Import

# %% [markdown]
# **Dataset auf INTEG Datenkatalog**: https://data.integ.stadt-zuerich.ch/dataset/bevolkerung-nach-5-jahresaltersklasse-und-statistischer-zone-ab-1911
#
# (int_dwh)

# %%
#Die Datasets sind nur zum Testen auf INT-DWH-Dropzone. Wenn der Test vorbei ist, sind sie auf PROD. 
# Über den Status kann man einfach switchen

status = "integ";
print(status)
# Out:
# integ

# %%
# Filepath
if status == "prod":
    #fp = r"\\szh\ssz\applikationen\OGD_Dropzone\DWH\bau_whg_bestand_umbau_ea_zizahlkat_kreis_saldo_jahr_OD5101\BAU510OD5101.csv"
    fp = r"https://ld.integ.stadt-zuerich.ch/statistics/view/V000003/observation/?format=csv"
else:
    fp = r"https://ld.integ.stadt-zuerich.ch/statistics/view/V000003/observation/?format=csv"
print(fp)
# Out:
# https://ld.integ.stadt-zuerich.ch/statistics/view/V000003/observation/?format=csv

# %%
# Read the data
data2betested = pd.read_csv(
    fp, 
    sep=',',
   #usecols=[0,1,2,3,4,6],
   #names=['stationid','year','month','avgtemp','latitude','longitude','elevation','station','countryid','country'],
   #skiprows=1,
   # parse_dates=[0],
    parse_dates=True,
    #date_parser=lambda x: pd.to_datetime(x, format="%Y"), 
    #index_col="date_time",
    low_memory=False    
    )
print('done')
# Out:
# done

# %% [markdown]
# In der Folge ein paar erste Tests:

# %%
type(data2betested)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
#  - 1) Zeige eine kurze Vorschau der importierten Daten
#  - 2) Weise die Datentypen aus
#  - 3) Zeige die Shape (Umfang) des Datensatzes an

# %%
data2betested.head(30000)
# Out:
#     BEWALT0501  BEWALT0502  BEWALT0511  BEWALT0512  BEWALT0513  BEWALT0514  BEWALT0515  ...  \
# 0          429         409         347         284         275         228         247  ...
# 1          581         439         796         685         576         458         314  ...
# 2          703         479        1172         960         794         742         592  ...
# 3          600         453         664         596         544         440         389  ...
# 4          657         828         701         630         445         393         338  ...
# 5         4145        3257        4401        3518        2997        2517        2299  ...
# 6         1433        1094        1535        1223        1018         880         841  ...
# 7          503         445         692         534         485         451         418  ...
# 8          200         179         378         327         248         207         211  ...
# 9          394         376         574         464         424         399         417  ...
# 10         413         294         676         519         360         284         184  ...
# 11        2055        1565        2505        2062        1748        1584        1480  ...
# 12         234         120         337         286         235         205         177  ...
# 13         577         460         749         639         577         472         444  ...
# 14         687         584         714         647         495         407         341  ...
# 15         385         175         773         585         408         298         229  ...
# 16        1028         701        1014         806         632         515         407  ...
# 17        1698        1376        2091        1618        1371        1223        1096  ...
# 18          11          17          39          28          24          26          20  ...
# 19         580         551         488         393         318         297         217  ...
# 20        1870        1665        2538        2105        1969        1749        1886  ...
# 21         258         169         230         207         147         104          90  ...
# 22        2876        2294        2973        2481        1873        1519        1290  ...
# 23       21939       17166       26116       21388       17832       15506       13868  ...
# 24         269         180         457         347         311         330         204  ...
# 25          83          67         240         208         196         187         166  ...
# 26        1278        1029        1487        1258        1138        1070        1056  ...
# 27         275         145         357         229         156         119          80  ...
# 28         385         290         500         382         381         318         296  ...
# 29        1665        1350        1585        1308        1138         947         850  ...
# 30        1165         827        1192        1043         955         946         783  ...
# 31         587         387         552         437         334         383         299  ...
# 32         688         439        1033         748         516         403         264  ...
# 33        1613        1348        2158        1732        1462        1260        1129  ...
# 34          22          19          70          59          51          56          69  ...
# 35        1224         783        1799        1477        1131         860         633  ...
# 36         151         121         418         357         305         302         284  ...
# 37         868         628        1071         930         745         646         639  ...
# 38         777         536        1018         804         610         514         424  ...
# 39        1867        1588        1866        1636        1357        1144         947  ...
# 40        1191         765        1258        1045         796         611         545  ...
# 41        1884        1424        1970        1651        1354        1257        1185  ...
# 42        1195         931        1399        1084         886         772         678  ...
# 43         514         539         715         620         587         560         729  ...
# 44        2778        2175        3350        2775        2417        2206        1912  ...
# 45        1047         813        1281         987         841         690         608  ...
# 46          35          18          69          62          34          33          29  ...
#
#     BEWALT0509  BEWALT0510  BEWALT9100    BEW                                               RAUM  \
# 0          457         441           1   6102  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 1         1003         900           1  13072  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 2         1366        1311           3  16192  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 3          699         694           2  11315  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 4          862         853           3  10698  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 5         5297        4720           9  72831  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 6         1860        1638           3  24991  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 7          797         835          10  10641  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 8          377         413           1   5086  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 9          596         628           1   7953  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 10         878         778           1   9608  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 11        3067        2825          12  38199  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 12         487         428           0   4990  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 13         891         875           5  11081  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 14         756         774           3  11930  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 15        1050         875           1  11169  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 16        1553        1249           3  17158  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 17        2640        2481          12  32867  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 18          36          29           1    641  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 19         597         553           1   8508  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 20        2868        2828          19  37053  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 21         405         349           3   4460  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 22        4133        3527          13  49195  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 23       32036       29462         106 410404  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 24         502         470           2   6116  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 25         220         234           0   3197  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 26        1736        1689           7  22320  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 27         527         462           0   5457  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 28         592         577           7   7380  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 29        1857        1674           4  25874  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 30        1529        1379           4  19325  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 31         774         688           3   9257  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 32        1405        1240           1  15065  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 33        2375        2242           4  32003  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 34          74          82           0    974  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 35        2458        2124           5  28701  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 36         390         432           1   5617  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 37        1225        1203          13  16244  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 38        1331        1136           5  15879  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 39        2052        2021           6  31753  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 40        1718        1425           7  21339  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 41        2456        2332          17  31603  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 42        1843        1646           2  22226  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 43         789         748           6  10639  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 44        3904        3621           8  51328  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 45        1580        1408           2  21966  https://ld.integ.stadt-zuerich.ch/statistics/c...
# 46          60          87           0    805  https://ld.integ.stadt-zuerich.ch/statistics/c...
#
#                                                  ZEIT      hasEnd
# 0   https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 1   https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 2   https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 3   https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 4   https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 5   https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 6   https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 7   https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 8   https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 9   https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 10  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 11  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 12  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 13  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 14  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 15  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 16  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 17  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 18  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 19  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 20  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 21  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 22  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 23  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 24  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 25  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 26  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 27  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 28  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 29  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 30  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 31  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 32  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 33  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 34  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 35  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 36  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 37  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 38  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 39  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 40  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 41  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 42  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 43  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 44  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 45  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
# 46  https://ld.integ.stadt-zuerich.ch/statistics/c...  2015-12-31
#
# [47 rows x 25 columns]

# %%
data2betested.dtypes
# Out:
# BEWALT0501    float64
# BEWALT0502    float64
# BEWALT0511    float64
# BEWALT0512    float64
# BEWALT0513    float64
# BEWALT0514    float64
# BEWALT0515    float64
# BEWALT0516    float64
# BEWALT0517    float64
# BEWALT0518    float64
# BEWALT0519    float64
# BEWALT0520    float64
# BEWALT0503    float64
# BEWALT0504    float64
# BEWALT0505    float64
# BEWALT0506    float64
# BEWALT0507    float64
# BEWALT0508    float64
# BEWALT0509    float64
# BEWALT0510    float64
# BEWALT9100    float64
# BEW           float64
# RAUM           object
# ZEIT           object
# hasEnd         object
# dtype: object

# %%
data2betested.shape
# Out:
# (47, 25)

# %% [markdown]
# Beschreibe einzelne Attribute

# %%
data2betested.describe()
# Out:
#        BEWALT0501  BEWALT0502  BEWALT0511  BEWALT0512  BEWALT0513  BEWALT0514  BEWALT0515  ...  \
# count          47          47          47          47          47          47          47  ...
# mean         1400        1096        1667        1365        1138         990         885  ...
# std          3174        2488        3757        3077        2569        2234        2004  ...
# min            11          17          39          28          24          26          20  ...
# 25%           390         292         494         388         326         300         238  ...
# 50%           687         539         796         685         577         472         418  ...
# 75%          1356        1062        1560        1283        1134         946         846  ...
# max         21939       17166       26116       21388       17832       15506       13868  ...
#
#        BEWALT0506  BEWALT0507  BEWALT0508  BEWALT0509  BEWALT0510  BEWALT9100    BEW
# count          47          47          47          47          47          47     47
# mean         2745        2940        2557        2045        1881           7  26196
# std          6215        6635        5766        4609        4233          15  59127
# min            85          44          41          36          29           0    641
# 25%           604         740         684         594         565           1   7666
# 50%          1560        1643        1475        1050         900           3  13072
# 75%          2748        2821        2410        1858        1682           7  25432
# max         43011       46057       40055       32036       29462         106 410404
#
# [8 rows x 22 columns]

# %% [markdown]
# Wie viele Nullwerte gibt es im Datensatz?

# %%
data2betested.isnull().sum()
# Out:
# BEWALT0501    0
# BEWALT0502    0
# BEWALT0511    0
# BEWALT0512    0
# BEWALT0513    0
# BEWALT0514    0
# BEWALT0515    0
# BEWALT0516    0
# BEWALT0517    0
# BEWALT0518    0
# BEWALT0519    0
# BEWALT0520    0
# BEWALT0503    0
# BEWALT0504    0
# BEWALT0505    0
# BEWALT0506    0
# BEWALT0507    0
# BEWALT0508    0
# BEWALT0509    0
# BEWALT0510    0
# BEWALT9100    0
# BEW           0
# RAUM          0
# ZEIT          0
# hasEnd        0
# dtype: int64

# %% [markdown]
# Wandle die Spalte Jahr von Int zu **Datetime** um. Dies wird in den meisten Grafiken so benötigt.

# %%
data2betested['ZEIT']=pd.to_datetime(data2betested['ZEIT'], format='%Y')
#data2betested['Jahr']=pd.to_datetime(data2betested['Jahr'], format='%Y')
#TO DO --> setze das Datum auf den 31.12. der Jahres.
#test=data2betested[['StichtagDatJahr']].date().replace(month=12, day=31)

data2betested
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     508         try:
# --> 509             values, tz = conversion.datetime_to_datetime64(arg)
#     510             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12876/3044502986.py in <module>
# ----> 1 data2betested['ZEIT']=pd.to_datetime(data2betested['ZEIT'], format='%Y')
#       2 #data2betested['Jahr']=pd.to_datetime(data2betested['Jahr'], format='%Y')
#       3 #TO DO --> setze das Datum auf den 31.12. der Jahres.
#       4 #test=data2betested[['StichtagDatJahr']].date().replace(month=12, day=31)
#       5
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     885             result = arg.map(cache_array)
#     886         else:
# --> 887             values = convert_listlike(arg._values, format)
#     888             result = arg._constructor(values, index=arg.index, name=arg.name)
#     889     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     391
#     392     if format is not None:
# --> 393         res = _to_datetime_with_format(
#     394             arg, orig_arg, name, tz, format, exact, errors, infer_datetime_format
#     395         )
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     511             return DatetimeIndex._simple_new(dta, name=name)
#     512         except (ValueError, TypeError):
# --> 513             raise err
#     514
#     515
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     498
#     499         # fallback
# --> 500         res = _array_strptime_with_fallback(
#     501             arg, name, tz, fmt, exact, errors, infer_datetime_format
#     502         )
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\pandas\core\tools\datetimes.py in _array_strptime_with_fallback(arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     434
#     435     try:
# --> 436         result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors)
#     437         if "%Z" in fmt or "%z" in fmt:
#     438             return _return_parsed_timezone_results(result, timezones, tz, name)
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\pandas\_libs\tslibs\strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data 'https://ld.integ.stadt-zuerich.ch/statistics/code/Z31122015' does not match format '%Y' (match)

# %% [markdown]
# Bereite die Daten für die Grafik unten vor

# %%
Jahre = data2betested.groupby("Jahr")
len(Jahre)
# Out:
# 6

# %%
for key, group in Jahre:
    print(key, len(group))
# Out:
# 2015-01-01 00:00:00 56
# 2016-01-01 00:00:00 74
# 2017-01-01 00:00:00 70
# 2018-01-01 00:00:00 74
# 2019-01-01 00:00:00 68
# 2020-01-01 00:00:00 72

# %%
myJahr = "2020-01-01"
aktuellesJahr=Jahre.get_group(myJahr)   
aktuellesJahr.head(3)
# Out:
#           Jahr  KreisCd KreisLang  EigentumsartCd               EigentumsartLang  \
# 342 2020-01-01        1   Kreis 1               3  Übrige private Gesellschaften
# 343 2020-01-01        1   Kreis 1               3  Übrige private Gesellschaften
# 344 2020-01-01        1   Kreis 1               4            Natürliche Personen
#
#                  Wohnungsgroesse  Wohnungssaldo
# 342    AnzGbdWhgStatZim1_3_saldo             -8
# 343  AnzGbdWhgStatZim4plus_saldo              4
# 344    AnzGbdWhgStatZim1_3_saldo             12

# %% [markdown]
# **Selektionen und Aggregationen**
#
# Check this [Doku](https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/)

# %%
   
test = data2betested.groupby(
   ['Jahr', 'Wohnungsgroesse']
).agg(
    {
         'Wohnungssaldo':(sum),     # Sum --> (sum)
         #'AnzPers': (sum),   
         #'Wohnungsfl': 'max'  
    }
)
test.head(10)
# Out:
#                                         Wohnungssaldo
# Jahr       Wohnungsgroesse
# 2015-01-01 AnzGbdWhgStatZim1_3_saldo              199
#            AnzGbdWhgStatZim4plus_saldo             25
# 2016-01-01 AnzGbdWhgStatZim1_3_saldo              254
#            AnzGbdWhgStatZim4plus_saldo             61
# 2017-01-01 AnzGbdWhgStatZim1_3_saldo              302
#            AnzGbdWhgStatZim4plus_saldo             44
# 2018-01-01 AnzGbdWhgStatZim1_3_saldo              267
#            AnzGbdWhgStatZim4plus_saldo             -4
# 2019-01-01 AnzGbdWhgStatZim1_3_saldo              160
#            AnzGbdWhgStatZim4plus_saldo             15

# %% [markdown]
# **Einfache Visualisierungen zur Plausi**

# %% [markdown]
# Exploriere die Daten mit Pivottable.JS

# %%
from pivottablejs import pivot_ui

pivot_ui(data2betested)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Liniendiagramm
# [Link zur Doku](https://altair-viz.github.io/gallery/multiline_highlight.html)

# %%
mySelection = aktuellesJahr[['Jahr', 'KreisCd', 'KreisLang', 'EigentumsartCd', 'EigentumsartLang', 'Wohnungssaldo']]
mySelection
# Out:
#           Jahr  KreisCd KreisLang  EigentumsartCd               EigentumsartLang  Wohnungssaldo
# 342 2020-01-01        1   Kreis 1               3  Übrige private Gesellschaften             -8
# 343 2020-01-01        1   Kreis 1               3  Übrige private Gesellschaften              4
# 344 2020-01-01        1   Kreis 1               4            Natürliche Personen             12
# 345 2020-01-01        1   Kreis 1               4            Natürliche Personen              0
# 346 2020-01-01       10  Kreis 10               2        Wohnbaugenossenschaften             -4
# ..         ...      ...       ...             ...                            ...            ...
# 409 2020-01-01        9   Kreis 9               3  Übrige private Gesellschaften              0
# 410 2020-01-01        9   Kreis 9               4            Natürliche Personen             41
# 411 2020-01-01        9   Kreis 9               4            Natürliche Personen            -10
# 412 2020-01-01        9   Kreis 9               5           Im Stockwerkeigentum             -1
# 413 2020-01-01        9   Kreis 9               5           Im Stockwerkeigentum              2
#
# [72 rows x 6 columns]

# %%
agg_mySelection = mySelection.groupby(
   ['Jahr', 'KreisCd', 'KreisLang', 'EigentumsartCd', 'EigentumsartLang']
).agg(
    {
         'Wohnungssaldo':(sum,min, max)     #, 'AnzPers': (sum, min, max)
    }
)
agg_mySelection.head()
# Out:
#                                                                           Wohnungssaldo
#                                                                                     sum min max
# Jahr       KreisCd KreisLang EigentumsartCd EigentumsartLang
# 2020-01-01 1       Kreis 1   3              Übrige private Gesellschaften            -4  -8   4
#                              4              Natürliche Personen                      12   0  12
#            2       Kreis 2   3              Übrige private Gesellschaften            30  -4  34
#                              4              Natürliche Personen                      10  -1  11
#            3       Kreis 3   2              Wohnbaugenossenschaften                   0   0   0

# %%
mySelection = aktuellesJahr[(aktuellesJahr.EigentumsartCd == 2) | (aktuellesJahr.EigentumsartCd == 4)]

mySelection.head()
# Out:
#           Jahr  KreisCd KreisLang  EigentumsartCd         EigentumsartLang  \
# 344 2020-01-01        1   Kreis 1               4      Natürliche Personen
# 345 2020-01-01        1   Kreis 1               4      Natürliche Personen
# 346 2020-01-01       10  Kreis 10               2  Wohnbaugenossenschaften
# 347 2020-01-01       10  Kreis 10               2  Wohnbaugenossenschaften
# 350 2020-01-01       10  Kreis 10               4      Natürliche Personen
#
#                  Wohnungsgroesse  Wohnungssaldo
# 344    AnzGbdWhgStatZim1_3_saldo             12
# 345  AnzGbdWhgStatZim4plus_saldo              0
# 346    AnzGbdWhgStatZim1_3_saldo             -4
# 347  AnzGbdWhgStatZim4plus_saldo              3
# 350    AnzGbdWhgStatZim1_3_saldo              9

# %%
# df_statzonen = df_statzonen[(df_statzonen.knr>0) & (df_statzonen.qname!="Hirslanden")]

highlight = alt.selection(type='single', on='mouseover',
                          fields=['Wohnungsgroesse'], nearest=True)
#x='date:StichtagDatJahr',
base = alt.Chart(mySelection).encode(
    x='KreisLang',
    y='Wohnungssaldo',
    color='Wohnungsgroesse'
)

points = base.mark_circle().encode(
    opacity=alt.value(0)
).add_selection(
    highlight
).properties(
    width=700 , height=300
)
lines = base.mark_line().encode(
    size=alt.condition(~highlight, alt.value(1.5), alt.value(4))
).interactive()

points + lines
# Out:
# alt.LayerChart(...)

# %%
alt.Chart(mySelection).mark_circle(size=60).encode(
    x='Wohnungssaldo',
    y='KreisLang',
    #color='AnzWhg',
    #color=alt.Color('EigentumsartLang', scale=alt.Scale(scheme='dark2')),
    color=alt.Color('Wohnungssaldo', scale=alt.Scale(scheme='greens')),
    tooltip=['Jahr', 'KreisCd', 'KreisLang', 'EigentumsartCd', 'EigentumsartLang', 'Wohnungsgroesse']
).interactive() # this makes the axes interactive: now you can zoom & pan
# Out:
# alt.Chart(...)
