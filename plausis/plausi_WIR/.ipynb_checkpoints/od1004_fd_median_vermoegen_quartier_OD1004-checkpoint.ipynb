# %% [markdown]
# **Importiere die notwendigen Packages**

# %%
#%pip install geopandas fiona requests folium mplleaflet contextily

# %%
import pandas as pd
import pivottablejs
from pivottablejs import pivot_ui
import numpy as np
import altair as alt
import matplotlib.pyplot as plt
from datetime import datetime
import geopandas as gpd
import folium 
import fiona
import requests
import mplleaflet
import seaborn as sns

# %% [markdown]
# Definiere Settings. Hier das Zahlenformat von Float-Werten (z.B. *'{:,.2f}'.format* mit Komma als Tausenderzeichen),

# %%
pd.options.display.float_format = '{:.0f}'.format
pd.set_option('display.width', 100)
pd.set_option('display.max_columns', 15)

# %% [markdown]
# Importiere einen Datensatz von der **DWH_INT** Dropzone.
#
# - Beachte dabei die Notation des Pfades...
# - Definiere mal aktuell noch keine weiteren Parameter beim Import

# %% [markdown]
# **Dataset auf INTEG Datenkatalog**: https://data.integ.stadt-zuerich.ch/dataset/int_dwh_fd_median_vermoegen_quartier_od1004

# %%
# Filepath
fp = r"//szh.loc/ssz/applikationen/OGD_Dropzone/INT_DWH/fd_median_vermoegen_quartier_OD1004/WIR100OD1004.csv "

# Read the data
data2betested = pd.read_csv(
    fp, 
    sep=',',
   #usecols=[0,1,2,3,4,6],
   #names=['stationid','year','month','avgtemp','latitude','longitude','elevation','station','countryid','country'],
   #skiprows=1,
   # parse_dates=[0],
    parse_dates=True,
    #date_parser=lambda x: pd.to_datetime(x, format="%Y"), 
    #index_col="date_time",
    low_memory=False    
    )
print("done")
# Out:
# done

# %% [markdown]
# In der Folge ein paar erste Tests:

# %%
type(data2betested)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
#  - 1) Zeige eine kurze Vorschau der importierten Daten
#  - 2) Weise die Datentypen aus
#  - 3) Zeige die Shape (Umfang) des Datensatzes an

# %%
data2betested
# Out:
#       SteuerJahr  QuarSort              QuarLang  SteuerTarifSort         SteuerTarifLang  \
# 0           1999        11               Rathaus                0              Grundtarif
# 1           1999        11               Rathaus                1      Verheiratetentarif
# 2           1999        11               Rathaus                2  Einelternfamilientarif
# 3           1999        12           Hochschulen                0              Grundtarif
# 4           1999        12           Hochschulen                1      Verheiratetentarif
# ...          ...       ...                   ...              ...                     ...
# 2035        2018       122  Schwamendingen-Mitte                1      Verheiratetentarif
# 2036        2018       122  Schwamendingen-Mitte                2  Einelternfamilientarif
# 2037        2018       123            Hirzenbach                0              Grundtarif
# 2038        2018       123            Hirzenbach                1      Verheiratetentarif
# 2039        2018       123            Hirzenbach                2  Einelternfamilientarif
#
#       SteuerVermoegen_p50  SteuerVermoegen_p25  SteuerVermoegen_p75
# 0                      20                    0                  150
# 1                     191                   30                  792
# 2                      23                    0                  406
# 3                      28                    0                  186
# 4                     249                   37                  724
# ...                   ...                  ...                  ...
# 2035                   36                    0                  226
# 2036                    0                    0                   21
# 2037                   12                    0                   69
# 2038                   37                    0                  178
# 2039                    1                    0                   25
#
# [2040 rows x 8 columns]

# %%
data2betested.dtypes
# Out:
# SteuerJahr               int64
# QuarSort                 int64
# QuarLang                object
# SteuerTarifSort          int64
# SteuerTarifLang         object
# SteuerVermoegen_p50    float64
# SteuerVermoegen_p25    float64
# SteuerVermoegen_p75    float64
# dtype: object

# %%
data2betested.shape
# Out:
# (2040, 8)

# %% [markdown]
# Beschreibe einzelne Attribute

# %%
data2betested.describe()
# Out:
#        SteuerJahr  QuarSort  SteuerTarifSort  SteuerVermoegen_p50  SteuerVermoegen_p25  \
# count        2040      2040             2040                 1982                 1982
# mean         2008        65                1                   84                   14
# std             6        36                1                  122                   31
# min          1999        11                0                    0                    0
# 25%          2004        33                0                   16                    0
# 50%          2008        67                1                   39                    1
# 75%          2013        92                2                   82                    8
# max          2018       123                2                  872                  219
#
#        SteuerVermoegen_p75
# count                 1982
# mean                   326
# std                    400
# min                      7
# 25%                     94
# 50%                    188
# 75%                    356
# max                   2621

# %% [markdown]
# Wie viele Nullwerte gibt es im Datensatz?

# %%
data2betested.isnull().sum()
# Out:
# SteuerJahr              0
# QuarSort                0
# QuarLang                0
# SteuerTarifSort         0
# SteuerTarifLang         0
# SteuerVermoegen_p50    58
# SteuerVermoegen_p25    58
# SteuerVermoegen_p75    58
# dtype: int64

# %% [markdown]
# Wandle die Spalte Jahr von Int zu **Datetime** um. Dies wird in den meisten Grafiken so benötigt.

# %%
data2betested['SteuerJahr']=pd.to_datetime(data2betested['SteuerJahr'], format='%Y')

#TO DO --> setze das Datum auf den 31.12. der Jahres.
#test=data2betested[['StichtagDatJahr']].date().replace(month=12, day=31)

data2betested
# Out:
#      SteuerJahr  QuarSort              QuarLang  SteuerTarifSort         SteuerTarifLang  \
# 0    1999-01-01        11               Rathaus                0              Grundtarif
# 1    1999-01-01        11               Rathaus                1      Verheiratetentarif
# 2    1999-01-01        11               Rathaus                2  Einelternfamilientarif
# 3    1999-01-01        12           Hochschulen                0              Grundtarif
# 4    1999-01-01        12           Hochschulen                1      Verheiratetentarif
# ...         ...       ...                   ...              ...                     ...
# 2035 2018-01-01       122  Schwamendingen-Mitte                1      Verheiratetentarif
# 2036 2018-01-01       122  Schwamendingen-Mitte                2  Einelternfamilientarif
# 2037 2018-01-01       123            Hirzenbach                0              Grundtarif
# 2038 2018-01-01       123            Hirzenbach                1      Verheiratetentarif
# 2039 2018-01-01       123            Hirzenbach                2  Einelternfamilientarif
#
#       SteuerVermoegen_p50  SteuerVermoegen_p25  SteuerVermoegen_p75
# 0                      20                    0                  150
# 1                     191                   30                  792
# 2                      23                    0                  406
# 3                      28                    0                  186
# 4                     249                   37                  724
# ...                   ...                  ...                  ...
# 2035                   36                    0                  226
# 2036                    0                    0                   21
# 2037                   12                    0                   69
# 2038                   37                    0                  178
# 2039                    1                    0                   25
#
# [2040 rows x 8 columns]

# %% [markdown]
# Bereite die Daten für die Grafik unten vor

# %%
Jahre = data2betested.groupby("SteuerJahr")
len(Jahre)
# Out:
# 20

# %%
for key, group in Jahre:
    print(key, len(group))
# Out:
# 1999-01-01 00:00:00 102
# 2000-01-01 00:00:00 102
# 2001-01-01 00:00:00 102
# 2002-01-01 00:00:00 102
# 2003-01-01 00:00:00 102
# 2004-01-01 00:00:00 102
# 2005-01-01 00:00:00 102
# 2006-01-01 00:00:00 102
# 2007-01-01 00:00:00 102
# 2008-01-01 00:00:00 102
# 2009-01-01 00:00:00 102
# 2010-01-01 00:00:00 102
# 2011-01-01 00:00:00 102
# 2012-01-01 00:00:00 102
# 2013-01-01 00:00:00 102
# 2014-01-01 00:00:00 102
# 2015-01-01 00:00:00 102
# 2016-01-01 00:00:00 102
# 2017-01-01 00:00:00 102
# 2018-01-01 00:00:00 102

# %%
myJahr = "2018-01-01"
aktuellesJahr=Jahre.get_group(myJahr)   
aktuellesJahr
# Out:
#      SteuerJahr  QuarSort              QuarLang  SteuerTarifSort         SteuerTarifLang  \
# 1938 2018-01-01        11               Rathaus                0              Grundtarif
# 1939 2018-01-01        11               Rathaus                1      Verheiratetentarif
# 1940 2018-01-01        11               Rathaus                2  Einelternfamilientarif
# 1941 2018-01-01        12           Hochschulen                0              Grundtarif
# 1942 2018-01-01        12           Hochschulen                1      Verheiratetentarif
# ...         ...       ...                   ...              ...                     ...
# 2035 2018-01-01       122  Schwamendingen-Mitte                1      Verheiratetentarif
# 2036 2018-01-01       122  Schwamendingen-Mitte                2  Einelternfamilientarif
# 2037 2018-01-01       123            Hirzenbach                0              Grundtarif
# 2038 2018-01-01       123            Hirzenbach                1      Verheiratetentarif
# 2039 2018-01-01       123            Hirzenbach                2  Einelternfamilientarif
#
#       SteuerVermoegen_p50  SteuerVermoegen_p25  SteuerVermoegen_p75
# 1938                   47                    2                  283
# 1939                  403                   80                 1557
# 1940                   80                    2                  532
# 1941                   55                    5                  311
# 1942                  567                  188                 1978
# ...                   ...                  ...                  ...
# 2035                   36                    0                  226
# 2036                    0                    0                   21
# 2037                   12                    0                   69
# 2038                   37                    0                  178
# 2039                    1                    0                   25
#
# [102 rows x 8 columns]

# %% [markdown]
# **Selektionen und Aggregationen**
#
# Check this [Doku](https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/)

# %%
#test = data2betested.groupby(['Quartal'])[['stzh_frau']].agg('median')
#test
# produces Pandas Series
    #data2betested.groupby(['StichtagDatJahr', 'KonOGDSort'])['AnzBestWir'].sum()
# Produces Pandas DataFrame
    #data2betested.groupby(['StichtagDatJahr', 'KonOGDSort'])[['AnzBestWir']].sum()

# %% [markdown]
# **Einfache Visualisierungen zur Plausi**

# %% [markdown]
# Exploriere die Daten mit Pivottable.JS

# %%
from pivottablejs import pivot_ui

pivot_ui(data2betested)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Liniendiagramm
# [Link zur Doku](https://altair-viz.github.io/gallery/multiline_highlight.html)

# %%
mySelection = data2betested[(data2betested.QuarSort >1) & (data2betested.SteuerJahr == "2018")] #data2betested.SteuerTarifLang=="Grundtarif") & 
#mySelection = data2betested[['SteuerJahr', 'QuarLang', 'SteuerEInkommen_p50']]
#selVZA = data2betested[['Jahr', 'Quartal', 'stzh_VZA_Frauen', 'stzh_VZA_Maenner', 'stzh_VZA_s2', 'stzh_VZA_s3']]

mySelection.head()
# Out:
#      SteuerJahr  QuarSort     QuarLang  SteuerTarifSort         SteuerTarifLang  \
# 1938 2018-01-01        11      Rathaus                0              Grundtarif
# 1939 2018-01-01        11      Rathaus                1      Verheiratetentarif
# 1940 2018-01-01        11      Rathaus                2  Einelternfamilientarif
# 1941 2018-01-01        12  Hochschulen                0              Grundtarif
# 1942 2018-01-01        12  Hochschulen                1      Verheiratetentarif
#
#       SteuerVermoegen_p50  SteuerVermoegen_p25  SteuerVermoegen_p75
# 1938                   47                    2                  283
# 1939                  403                   80                 1557
# 1940                   80                    2                  532
# 1941                   55                    5                  311
# 1942                  567                  188                 1978

# %%
myGraph = mySelection
myGraph.head()
# Out:
#      SteuerJahr  QuarSort     QuarLang  SteuerTarifSort         SteuerTarifLang  \
# 1938 2018-01-01        11      Rathaus                0              Grundtarif
# 1939 2018-01-01        11      Rathaus                1      Verheiratetentarif
# 1940 2018-01-01        11      Rathaus                2  Einelternfamilientarif
# 1941 2018-01-01        12  Hochschulen                0              Grundtarif
# 1942 2018-01-01        12  Hochschulen                1      Verheiratetentarif
#
#       SteuerVermoegen_p50  SteuerVermoegen_p25  SteuerVermoegen_p75
# 1938                   47                    2                  283
# 1939                  403                   80                 1557
# 1940                   80                    2                  532
# 1941                   55                    5                  311
# 1942                  567                  188                 1978

# %%
# df_statzonen = df_statzonen[(df_statzonen.knr>0) & (df_statzonen.qname!="Hirslanden")]
#aktuellesJahr[[aktuellesJahr.KreisSort =7]])
highlight = alt.selection(type='single', on='mouseover',
                          fields=['SteuerTarifLang'], nearest=True)
#x='date:StichtagDatJahr',
base = alt.Chart(myGraph).encode(
    x='QuarLang',
    y='SteuerVermoegen_p50',
    color='SteuerTarifLang'
)

points = base.mark_circle().encode(
    opacity=alt.value(0)
).add_selection(
    highlight
).properties(
    width=700 , height=300
)
lines = base.mark_line().encode(
    size=alt.condition(~highlight, alt.value(1.5), alt.value(4))
).interactive()

points + lines
# Out:
# alt.LayerChart(...)

# %%
alt.Chart(myGraph).mark_circle(size=60).encode(
    x='QuarLang',
    y='SteuerVermoegen_p50',
    color='SteuerTarifLang',
    tooltip=['SteuerJahr','QuarLang','SteuerVermoegen_p25', 'SteuerVermoegen_p50','SteuerVermoegen_p75']
).interactive() # this makes the axes interactive: now you can zoom & pan
# Out:
# alt.Chart(...)

# %%
import seaborn as sns
sns.set(style="darkgrid")
sns.histplot(data=myGraph, x="SteuerVermoegen_p50") #, y="KonOGDKurz")
plt.show();

# %% [markdown]
# Test: Choroplethenkarte

# %% [markdown]
# **Test: Choroplethenkarte**
# Importiere die Geodaten als GeoJSON

# %%
# Read abt. Geopandas https://geopandas.org/docs/user_guide/io.html
# Filepath statzonen
geojson_url = "https://www.ogd.stadt-zuerich.ch/wfs/geoportal/Statistische_Quartiere?service=WFS&version=1.1.0&request=GetFeature&outputFormat=GeoJSON&typename=adm_statistische_quartiere_map"
df_adm_statistische_quartiere_map = gpd.read_file(geojson_url)

df_adm_statistische_quartiere_map.head(5)
# Out:
#                                  id    kname  knr  objectid objid       qname  qnr  \
# 0  adm_statistische_quartiere_map.1  Kreis 7    7         1    34  Hirslanden   73
# 1  adm_statistische_quartiere_map.2  Kreis 8    8         2    33     Weinegg   83
# 2  adm_statistische_quartiere_map.3  Kreis 8    8         3    32   Mühlebach   82
# 3  adm_statistische_quartiere_map.4  Kreis 8    8         4    31     Seefeld   81
# 4  adm_statistische_quartiere_map.7  Kreis 4    4         7    16        Werd   41
#
#                                             geometry
# 0  POLYGON ((8.55670 47.36406, 8.55682 47.36410, ...
# 1  POLYGON ((8.55670 47.36405, 8.55672 47.36403, ...
# 2  POLYGON ((8.55423 47.36456, 8.55426 47.36452, ...
# 3  POLYGON ((8.54795 47.36500, 8.54805 47.36489, ...
# 4  POLYGON ((8.53300 47.37394, 8.53299 47.37392, ...

# %% [markdown]
# Joine die importierten statistischen Daten des aktuellen Jahres zum Geodatensatz:
#
# *Siehe dazu Doku zu [Geopandas](https://geopandas.org/docs/user_guide/mergingdata.html)*

# %%
selectMapAttr1 = data2betested[(data2betested.SteuerTarifLang=="Grundtarif") & (data2betested.SteuerJahr == "2018")]
selectMapAttr2 = data2betested[(data2betested.SteuerTarifLang=="Verheiratetentarif") & (data2betested.SteuerJahr == "2018")]

# %%
selectMapAttr1.head()
# Out:
#      SteuerJahr  QuarSort     QuarLang  SteuerTarifSort SteuerTarifLang  SteuerVermoegen_p50  \
# 1938 2018-01-01        11      Rathaus                0      Grundtarif                   47
# 1941 2018-01-01        12  Hochschulen                0      Grundtarif                   55
# 1944 2018-01-01        13    Lindenhof                0      Grundtarif                   75
# 1947 2018-01-01        14         City                0      Grundtarif                   21
# 1950 2018-01-01        21  Wollishofen                0      Grundtarif                   43
#
#       SteuerVermoegen_p25  SteuerVermoegen_p75
# 1938                    2                  283
# 1941                    5                  311
# 1944                    5                  401
# 1947                    1                  166
# 1950                    4                  197

# %%
# Rename attribute stznr to StatZoneSort, so the IDs have the same name

stadtquartiere_shapes = df_adm_statistische_quartiere_map[['geometry', 'qnr', 'qname', 'knr']].rename(columns={'qnr': 'QuarSort'})

# Merge with `merge` method on shared variable (stznr und StatZoneSort):
stadtquartiere_shapes_joined = stadtquartiere_shapes.merge(selectMapAttr1, on='QuarSort')

stadtquartiere_shapes_joined.head(3)
# Out:
#                                             geometry  QuarSort       qname  knr SteuerJahr  \
# 0  POLYGON ((8.55670 47.36406, 8.55682 47.36410, ...        73  Hirslanden    7 2018-01-01
# 1  POLYGON ((8.55670 47.36405, 8.55672 47.36403, ...        83     Weinegg    8 2018-01-01
# 2  POLYGON ((8.55423 47.36456, 8.55426 47.36452, ...        82   Mühlebach    8 2018-01-01
#
#      QuarLang  SteuerTarifSort SteuerTarifLang  SteuerVermoegen_p50  SteuerVermoegen_p25  \
# 0  Hirslanden                0      Grundtarif                   66                   10
# 1     Weinegg                0      Grundtarif                   60                    6
# 2   Mühlebach                0      Grundtarif                   67                    7
#
#    SteuerVermoegen_p75
# 0                  308
# 1                  294
# 2                  300

# %%
# Plot by StatQuartiere

stadtquartiere_shapes_joined.plot(column='SteuerVermoegen_p50', cmap='viridis', scheme='natural_breaks', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html

stadtquartiere_shapes_joined.plot(column='SteuerVermoegen_p50', cmap='plasma', scheme='quantiles', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html
stadtquartiere_shapes_joined.plot(column='SteuerVermoegen_p50', cmap='cool', scheme='fisherjenks', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html

stadtquartiere_shapes_joined.plot(column='SteuerVermoegen_p50', cmap='viridis', scheme='natural_breaks', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html
# Out:
# <AxesSubplot:>

# %% [markdown]
# ----------------------------------------------------------------------------------------

# %% [markdown]
# #Link https://automating-gis-processes.github.io/site/notebooks/L5/interactive-map-folium.html
#
# # Create a Map instance
# m = folium.Map(location=[60.25, 24.8], tiles = 'cartodbpositron', zoom_start=10, control_scale=True)
#
# # Plot a choropleth map
# # Notice: 'geoid' column that we created earlier needs to be assigned always as the first column
# folium.Choropleth(
#     geo_data=data,
#     name='Population in 2018',
#     data=data,
#     columns=['geoid', 'pop18'],
#     key_on='feature.id',
#     fill_color='YlOrRd',
#     fill_opacity=0.7,
#     line_opacity=0.2,
#     line_color='white',
#     line_weight=0,
#     highlight=False,
#     smooth_factor=1.0,
#     #threshold_scale=[100, 250, 500, 1000, 2000],
#     legend_name= 'Population in Helsinki').add_to(m)
#
# #Show map
# m

# %% [markdown]
# Noch zu prüfen, folgendes schöne Beispiel: https://docs.bokeh.org/en/latest/docs/user_guide/interaction/legends.html
#
# Konkrete Beispiele von Bookeh in Jupyter NB: https://docs.bokeh.org/en/latest/docs/user_guide/jupyter.html
