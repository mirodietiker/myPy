# %% [markdown]
# **Importiere die notwendigen Packages**

# %%
# Empfehlung für Colab: Installiere alles was Du brauchst
# %pip install pandas pivottablejs numpy altair matplotlib geopandas folium

# %%
import pandas as pd
import pivottablejs
from pivottablejs import pivot_ui
import numpy as np
import altair as alt
import matplotlib.pyplot as plt
from datetime import datetime
import geopandas as gpd
import folium

# %% [markdown]
# Definiere Settings. Hier das Zahlenformat von Float-Werten (z.B. *'{:,.2f}'.format* mit Komma als Tausenderzeichen),

# %%
pd.options.display.float_format = '{:.0f}'.format
pd.set_option('display.width', 100)
pd.set_option('display.max_columns', 15)

# %% [markdown]
# Importiere einen Datensatz von der **DWH_INT** Dropzone.
#
# - Beachte dabei die Notation des Pfades...
# - Definiere mal aktuell noch keine weiteren Parameter beim Import

# %% [markdown]
# **Dataset auf INTEG Datenkatalog**: https://data.integ.stadt-zuerich.ch/dataset/int_dwh_bau_whg_bestand_umbau_umbaukat_ea_zizahlkat_kreis_saldo_jahr_od5102
#
# (int_dwh)

# %%
# Filepath
fp = r"\\szh\ssz\applikationen\OGD_Dropzone\INT_DWH\bau_whg_bestand_umbau_umbaukat_ea_zizahlkat_kreis_saldo_jahr_OD5102\BAU510OD5102.csv"
#\\szh\ssz\applikationen\OGD_Dropzone\INT_DWH\bau_whg_bestand_umbau_ea_zizahlkat_kreis_saldo_jahr_OD5101\BAU510OD5101.csv


# Read the data
data2betested = pd.read_csv(
    fp, 
    sep=',',
   #usecols=[0,1,2,3,4,6],
   #names=['stationid','year','month','avgtemp','latitude','longitude','elevation','station','countryid','country'],
   #skiprows=1,
   # parse_dates=[0],
    parse_dates=True,
    #date_parser=lambda x: pd.to_datetime(x, format="%Y"), 
    #index_col="date_time",
    low_memory=False    
    )
print('done')
# Out:
# done

# %% [markdown]
# In der Folge ein paar erste Tests:

# %%
type(data2betested)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
#  - 1) Zeige eine kurze Vorschau der importierten Daten
#  - 2) Weise die Datentypen aus
#  - 3) Zeige die Shape (Umfang) des Datensatzes an

# %%
data2betested.head(30000)
# Out:
#     Jahr  Umbaukategorie          UmbaukategorieCd              Wohnungsgroesse  Wert
# 0   2015               3         Aufstockung/Anbau    AnzGbdWhgStatZim1_3_saldo    77
# 1   2015               3         Aufstockung/Anbau  AnzGbdWhgStatZim4plus_saldo     7
# 2   2015               2           Innere Reserven  AnzGbdWhgStatZim4plus_saldo    13
# 3   2015               2           Innere Reserven    AnzGbdWhgStatZim1_3_saldo    25
# 4   2015               1          Reine Erneuerung    AnzGbdWhgStatZim1_3_saldo   -24
# 5   2015               1          Reine Erneuerung  AnzGbdWhgStatZim4plus_saldo     5
# 6   2015               5  Umnutzung zu Nichtwohnen  AnzGbdWhgStatZim4plus_saldo   -11
# 7   2015               5  Umnutzung zu Nichtwohnen    AnzGbdWhgStatZim1_3_saldo    -1
# 8   2015               4       Umnutzung zu Wohnen    AnzGbdWhgStatZim1_3_saldo   122
# 9   2015               4       Umnutzung zu Wohnen  AnzGbdWhgStatZim4plus_saldo    11
# 10  2016               3         Aufstockung/Anbau    AnzGbdWhgStatZim1_3_saldo   163
# 11  2016               3         Aufstockung/Anbau  AnzGbdWhgStatZim4plus_saldo     3
# 12  2016               2           Innere Reserven    AnzGbdWhgStatZim1_3_saldo    77
# 13  2016               2           Innere Reserven  AnzGbdWhgStatZim4plus_saldo    39
# 14  2016               1          Reine Erneuerung  AnzGbdWhgStatZim4plus_saldo    12
# 15  2016               1          Reine Erneuerung    AnzGbdWhgStatZim1_3_saldo   -47
# 16  2016               5  Umnutzung zu Nichtwohnen    AnzGbdWhgStatZim1_3_saldo   -54
# 17  2016               5  Umnutzung zu Nichtwohnen  AnzGbdWhgStatZim4plus_saldo    -7
# 18  2016               4       Umnutzung zu Wohnen  AnzGbdWhgStatZim4plus_saldo    14
# 19  2016               4       Umnutzung zu Wohnen    AnzGbdWhgStatZim1_3_saldo   115
# 20  2017               3         Aufstockung/Anbau  AnzGbdWhgStatZim4plus_saldo    42
# 21  2017               3         Aufstockung/Anbau    AnzGbdWhgStatZim1_3_saldo   142
# 22  2017               2           Innere Reserven  AnzGbdWhgStatZim4plus_saldo    15
# 23  2017               2           Innere Reserven    AnzGbdWhgStatZim1_3_saldo    74
# 24  2017               1          Reine Erneuerung  AnzGbdWhgStatZim4plus_saldo    -9
# 25  2017               1          Reine Erneuerung    AnzGbdWhgStatZim1_3_saldo     2
# 26  2017               5  Umnutzung zu Nichtwohnen  AnzGbdWhgStatZim4plus_saldo   -14
# 27  2017               5  Umnutzung zu Nichtwohnen    AnzGbdWhgStatZim1_3_saldo   -48
# 28  2017               4       Umnutzung zu Wohnen  AnzGbdWhgStatZim4plus_saldo    10
# 29  2017               4       Umnutzung zu Wohnen    AnzGbdWhgStatZim1_3_saldo   132
# 30  2018               3         Aufstockung/Anbau  AnzGbdWhgStatZim4plus_saldo     9
# 31  2018               3         Aufstockung/Anbau    AnzGbdWhgStatZim1_3_saldo    99
# 32  2018               2           Innere Reserven  AnzGbdWhgStatZim4plus_saldo     0
# 33  2018               2           Innere Reserven    AnzGbdWhgStatZim1_3_saldo    86
# 34  2018               1          Reine Erneuerung    AnzGbdWhgStatZim1_3_saldo    31
# 35  2018               1          Reine Erneuerung  AnzGbdWhgStatZim4plus_saldo   -11
# 36  2018               5  Umnutzung zu Nichtwohnen  AnzGbdWhgStatZim4plus_saldo   -15
# 37  2018               5  Umnutzung zu Nichtwohnen    AnzGbdWhgStatZim1_3_saldo   -16
# 38  2018               4       Umnutzung zu Wohnen  AnzGbdWhgStatZim4plus_saldo    13
# 39  2018               4       Umnutzung zu Wohnen    AnzGbdWhgStatZim1_3_saldo    67
# 40  2019               3         Aufstockung/Anbau  AnzGbdWhgStatZim4plus_saldo    -1
# 41  2019               3         Aufstockung/Anbau    AnzGbdWhgStatZim1_3_saldo   149
# 42  2019               2           Innere Reserven  AnzGbdWhgStatZim4plus_saldo    15
# 43  2019               2           Innere Reserven    AnzGbdWhgStatZim1_3_saldo    91
# 44  2019               1          Reine Erneuerung  AnzGbdWhgStatZim4plus_saldo     6
# 45  2019               1          Reine Erneuerung    AnzGbdWhgStatZim1_3_saldo   -20
# 46  2019               5  Umnutzung zu Nichtwohnen  AnzGbdWhgStatZim4plus_saldo    -9
# 47  2019               5  Umnutzung zu Nichtwohnen    AnzGbdWhgStatZim1_3_saldo  -153
# 48  2019               4       Umnutzung zu Wohnen  AnzGbdWhgStatZim4plus_saldo     4
# 49  2019               4       Umnutzung zu Wohnen    AnzGbdWhgStatZim1_3_saldo    93
# 50  2020               3         Aufstockung/Anbau  AnzGbdWhgStatZim4plus_saldo    -3
# 51  2020               3         Aufstockung/Anbau    AnzGbdWhgStatZim1_3_saldo    78
# 52  2020               2           Innere Reserven  AnzGbdWhgStatZim4plus_saldo   -11
# 53  2020               2           Innere Reserven    AnzGbdWhgStatZim1_3_saldo   159
# 54  2020               1          Reine Erneuerung  AnzGbdWhgStatZim4plus_saldo     0
# 55  2020               1          Reine Erneuerung    AnzGbdWhgStatZim1_3_saldo    16
# 56  2020               5  Umnutzung zu Nichtwohnen  AnzGbdWhgStatZim4plus_saldo    -4
# 57  2020               5  Umnutzung zu Nichtwohnen    AnzGbdWhgStatZim1_3_saldo   -21
# 58  2020               4       Umnutzung zu Wohnen  AnzGbdWhgStatZim4plus_saldo    18
# 59  2020               4       Umnutzung zu Wohnen    AnzGbdWhgStatZim1_3_saldo   211

# %%
data2betested.dtypes
# Out:
# Jahr                 int64
# Umbaukategorie       int64
# UmbaukategorieCd    object
# Wohnungsgroesse     object
# Wert                 int64
# dtype: object

# %%
data2betested.shape
# Out:
# (60, 5)

# %% [markdown]
# Beschreibe einzelne Attribute

# %%
data2betested.describe()
# Out:
#        Jahr  Umbaukategorie  Wert
# count    60              60    60
# mean   2018               3    29
# std       2               1    63
# min    2015               1  -153
# 25%    2016               2    -8
# 50%    2018               3    10
# 75%    2019               4    75
# max    2020               5   211

# %% [markdown]
# Wie viele Nullwerte gibt es im Datensatz?

# %%
data2betested.isnull().sum()
# Out:
# Jahr                0
# Umbaukategorie      0
# UmbaukategorieCd    0
# Wohnungsgroesse     0
# Wert                0
# dtype: int64

# %% [markdown]
# Wandle die Spalte Jahr von Int zu **Datetime** um. Dies wird in den meisten Grafiken so benötigt.

# %%
data2betested['Jahr']=pd.to_datetime(data2betested['Jahr'], format='%Y')
#data2betested['Jahr']=pd.to_datetime(data2betested['Jahr'], format='%Y')
#TO DO --> setze das Datum auf den 31.12. der Jahres.
#test=data2betested[['StichtagDatJahr']].date().replace(month=12, day=31)

data2betested
# Out:
#          Jahr  Umbaukategorie          UmbaukategorieCd              Wohnungsgroesse  Wert
# 0  2015-01-01               3         Aufstockung/Anbau    AnzGbdWhgStatZim1_3_saldo    77
# 1  2015-01-01               3         Aufstockung/Anbau  AnzGbdWhgStatZim4plus_saldo     7
# 2  2015-01-01               2           Innere Reserven  AnzGbdWhgStatZim4plus_saldo    13
# 3  2015-01-01               2           Innere Reserven    AnzGbdWhgStatZim1_3_saldo    25
# 4  2015-01-01               1          Reine Erneuerung    AnzGbdWhgStatZim1_3_saldo   -24
# 5  2015-01-01               1          Reine Erneuerung  AnzGbdWhgStatZim4plus_saldo     5
# 6  2015-01-01               5  Umnutzung zu Nichtwohnen  AnzGbdWhgStatZim4plus_saldo   -11
# 7  2015-01-01               5  Umnutzung zu Nichtwohnen    AnzGbdWhgStatZim1_3_saldo    -1
# 8  2015-01-01               4       Umnutzung zu Wohnen    AnzGbdWhgStatZim1_3_saldo   122
# 9  2015-01-01               4       Umnutzung zu Wohnen  AnzGbdWhgStatZim4plus_saldo    11
# 10 2016-01-01               3         Aufstockung/Anbau    AnzGbdWhgStatZim1_3_saldo   163
# 11 2016-01-01               3         Aufstockung/Anbau  AnzGbdWhgStatZim4plus_saldo     3
# 12 2016-01-01               2           Innere Reserven    AnzGbdWhgStatZim1_3_saldo    77
# 13 2016-01-01               2           Innere Reserven  AnzGbdWhgStatZim4plus_saldo    39
# 14 2016-01-01               1          Reine Erneuerung  AnzGbdWhgStatZim4plus_saldo    12
# 15 2016-01-01               1          Reine Erneuerung    AnzGbdWhgStatZim1_3_saldo   -47
# 16 2016-01-01               5  Umnutzung zu Nichtwohnen    AnzGbdWhgStatZim1_3_saldo   -54
# 17 2016-01-01               5  Umnutzung zu Nichtwohnen  AnzGbdWhgStatZim4plus_saldo    -7
# 18 2016-01-01               4       Umnutzung zu Wohnen  AnzGbdWhgStatZim4plus_saldo    14
# 19 2016-01-01               4       Umnutzung zu Wohnen    AnzGbdWhgStatZim1_3_saldo   115
# 20 2017-01-01               3         Aufstockung/Anbau  AnzGbdWhgStatZim4plus_saldo    42
# 21 2017-01-01               3         Aufstockung/Anbau    AnzGbdWhgStatZim1_3_saldo   142
# 22 2017-01-01               2           Innere Reserven  AnzGbdWhgStatZim4plus_saldo    15
# 23 2017-01-01               2           Innere Reserven    AnzGbdWhgStatZim1_3_saldo    74
# 24 2017-01-01               1          Reine Erneuerung  AnzGbdWhgStatZim4plus_saldo    -9
# 25 2017-01-01               1          Reine Erneuerung    AnzGbdWhgStatZim1_3_saldo     2
# 26 2017-01-01               5  Umnutzung zu Nichtwohnen  AnzGbdWhgStatZim4plus_saldo   -14
# 27 2017-01-01               5  Umnutzung zu Nichtwohnen    AnzGbdWhgStatZim1_3_saldo   -48
# 28 2017-01-01               4       Umnutzung zu Wohnen  AnzGbdWhgStatZim4plus_saldo    10
# 29 2017-01-01               4       Umnutzung zu Wohnen    AnzGbdWhgStatZim1_3_saldo   132
# 30 2018-01-01               3         Aufstockung/Anbau  AnzGbdWhgStatZim4plus_saldo     9
# 31 2018-01-01               3         Aufstockung/Anbau    AnzGbdWhgStatZim1_3_saldo    99
# 32 2018-01-01               2           Innere Reserven  AnzGbdWhgStatZim4plus_saldo     0
# 33 2018-01-01               2           Innere Reserven    AnzGbdWhgStatZim1_3_saldo    86
# 34 2018-01-01               1          Reine Erneuerung    AnzGbdWhgStatZim1_3_saldo    31
# 35 2018-01-01               1          Reine Erneuerung  AnzGbdWhgStatZim4plus_saldo   -11
# 36 2018-01-01               5  Umnutzung zu Nichtwohnen  AnzGbdWhgStatZim4plus_saldo   -15
# 37 2018-01-01               5  Umnutzung zu Nichtwohnen    AnzGbdWhgStatZim1_3_saldo   -16
# 38 2018-01-01               4       Umnutzung zu Wohnen  AnzGbdWhgStatZim4plus_saldo    13
# 39 2018-01-01               4       Umnutzung zu Wohnen    AnzGbdWhgStatZim1_3_saldo    67
# 40 2019-01-01               3         Aufstockung/Anbau  AnzGbdWhgStatZim4plus_saldo    -1
# 41 2019-01-01               3         Aufstockung/Anbau    AnzGbdWhgStatZim1_3_saldo   149
# 42 2019-01-01               2           Innere Reserven  AnzGbdWhgStatZim4plus_saldo    15
# 43 2019-01-01               2           Innere Reserven    AnzGbdWhgStatZim1_3_saldo    91
# 44 2019-01-01               1          Reine Erneuerung  AnzGbdWhgStatZim4plus_saldo     6
# 45 2019-01-01               1          Reine Erneuerung    AnzGbdWhgStatZim1_3_saldo   -20
# 46 2019-01-01               5  Umnutzung zu Nichtwohnen  AnzGbdWhgStatZim4plus_saldo    -9
# 47 2019-01-01               5  Umnutzung zu Nichtwohnen    AnzGbdWhgStatZim1_3_saldo  -153
# 48 2019-01-01               4       Umnutzung zu Wohnen  AnzGbdWhgStatZim4plus_saldo     4
# 49 2019-01-01               4       Umnutzung zu Wohnen    AnzGbdWhgStatZim1_3_saldo    93
# 50 2020-01-01               3         Aufstockung/Anbau  AnzGbdWhgStatZim4plus_saldo    -3
# 51 2020-01-01               3         Aufstockung/Anbau    AnzGbdWhgStatZim1_3_saldo    78
# 52 2020-01-01               2           Innere Reserven  AnzGbdWhgStatZim4plus_saldo   -11
# 53 2020-01-01               2           Innere Reserven    AnzGbdWhgStatZim1_3_saldo   159
# 54 2020-01-01               1          Reine Erneuerung  AnzGbdWhgStatZim4plus_saldo     0
# 55 2020-01-01               1          Reine Erneuerung    AnzGbdWhgStatZim1_3_saldo    16
# 56 2020-01-01               5  Umnutzung zu Nichtwohnen  AnzGbdWhgStatZim4plus_saldo    -4
# 57 2020-01-01               5  Umnutzung zu Nichtwohnen    AnzGbdWhgStatZim1_3_saldo   -21
# 58 2020-01-01               4       Umnutzung zu Wohnen  AnzGbdWhgStatZim4plus_saldo    18
# 59 2020-01-01               4       Umnutzung zu Wohnen    AnzGbdWhgStatZim1_3_saldo   211

# %% [markdown]
# Bereite die Daten für die Grafik unten vor

# %%
Jahre = data2betested.groupby("Jahr")
len(Jahre)
# Out:
# 6

# %%
for key, group in Jahre:
    print(key, len(group))
# Out:
# 2015-01-01 00:00:00 10
# 2016-01-01 00:00:00 10
# 2017-01-01 00:00:00 10
# 2018-01-01 00:00:00 10
# 2019-01-01 00:00:00 10
# 2020-01-01 00:00:00 10

# %%
myJahr = "2020-01-01"
aktuellesJahr=Jahre.get_group(myJahr)   
aktuellesJahr.head(3)
# Out:
#          Jahr  Umbaukategorie   UmbaukategorieCd              Wohnungsgroesse  Wert
# 50 2020-01-01               3  Aufstockung/Anbau  AnzGbdWhgStatZim4plus_saldo    -3
# 51 2020-01-01               3  Aufstockung/Anbau    AnzGbdWhgStatZim1_3_saldo    78
# 52 2020-01-01               2    Innere Reserven  AnzGbdWhgStatZim4plus_saldo   -11

# %% [markdown]
# **Selektionen und Aggregationen**
#
# Check this [Doku](https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/)

# %%
   
test = data2betested.groupby(
   ['Jahr', 'UmbaukategorieCd', 'Umbaukategorie' ]
).agg(
    {
         'Wert':(sum),     # Sum --> (sum)
         #'AnzPers': (sum),   
         #'Wohnungsfl': 'max'  
    }
)
test.head(10)
# Out:
#                                                     Wert
# Jahr       UmbaukategorieCd         Umbaukategorie
# 2015-01-01 Aufstockung/Anbau        3                 84
#            Innere Reserven          2                 38
#            Reine Erneuerung         1                -19
#            Umnutzung zu Nichtwohnen 5                -12
#            Umnutzung zu Wohnen      4                133
# 2016-01-01 Aufstockung/Anbau        3                166
#            Innere Reserven          2                116
#            Reine Erneuerung         1                -35
#            Umnutzung zu Nichtwohnen 5                -61
#            Umnutzung zu Wohnen      4                129

# %% [markdown]
# **Einfache Visualisierungen zur Plausi**

# %% [markdown]
# Exploriere die Daten mit Pivottable.JS

# %%
from pivottablejs import pivot_ui

pivot_ui(data2betested)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Liniendiagramm
# [Link zur Doku](https://altair-viz.github.io/gallery/multiline_highlight.html)

# %%
mySelection = aktuellesJahr[['Jahr', 'UmbaukategorieCd', 'Umbaukategorie', 'Wohnungsgroesse', 'Wert']]
mySelection
# Out:
#          Jahr          UmbaukategorieCd  Umbaukategorie              Wohnungsgroesse  Wert
# 50 2020-01-01         Aufstockung/Anbau               3  AnzGbdWhgStatZim4plus_saldo    -3
# 51 2020-01-01         Aufstockung/Anbau               3    AnzGbdWhgStatZim1_3_saldo    78
# 52 2020-01-01           Innere Reserven               2  AnzGbdWhgStatZim4plus_saldo   -11
# 53 2020-01-01           Innere Reserven               2    AnzGbdWhgStatZim1_3_saldo   159
# 54 2020-01-01          Reine Erneuerung               1  AnzGbdWhgStatZim4plus_saldo     0
# 55 2020-01-01          Reine Erneuerung               1    AnzGbdWhgStatZim1_3_saldo    16
# 56 2020-01-01  Umnutzung zu Nichtwohnen               5  AnzGbdWhgStatZim4plus_saldo    -4
# 57 2020-01-01  Umnutzung zu Nichtwohnen               5    AnzGbdWhgStatZim1_3_saldo   -21
# 58 2020-01-01       Umnutzung zu Wohnen               4  AnzGbdWhgStatZim4plus_saldo    18
# 59 2020-01-01       Umnutzung zu Wohnen               4    AnzGbdWhgStatZim1_3_saldo   211

# %%
agg_mySelection = mySelection.groupby(
   ['Jahr', 'UmbaukategorieCd', 'Umbaukategorie', 'Wert']
).agg(
    {
         'Wert':(sum,min,max)
    }
)
agg_mySelection
# Out:
#                                                         Wert
#                                                          sum  min  max
# Jahr       UmbaukategorieCd         Umbaukategorie Wert
# 2020-01-01 Aufstockung/Anbau        3              -3     -3   -3   -3
#                                                     78    78   78   78
#            Innere Reserven          2              -11   -11  -11  -11
#                                                     159  159  159  159
#            Reine Erneuerung         1               0      0    0    0
#                                                     16    16   16   16
#            Umnutzung zu Nichtwohnen 5              -21   -21  -21  -21
#                                                    -4     -4   -4   -4
#            Umnutzung zu Wohnen      4               18    18   18   18
#                                                     211  211  211  211

# %%
mySelection = aktuellesJahr[(aktuellesJahr.EigentumsartCd == 2) | (aktuellesJahr.EigentumsartCd == 4)]

mySelection.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6516/1530925247.py in <module>
# ----> 1 mySelection = aktuellesJahr[(aktuellesJahr.EigentumsartCd == 2) | (aktuellesJahr.EigentumsartCd == 4)]
#       2
#       3 mySelection.head()
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'EigentumsartCd'

# %%
# df_statzonen = df_statzonen[(df_statzonen.knr>0) & (df_statzonen.qname!="Hirslanden")]

highlight = alt.selection(type='single', on='mouseover',
                          fields=['Wohnungsgroesse'], nearest=True)
#x='date:StichtagDatJahr',
base = alt.Chart(mySelection).encode(
    x='KreisLang',
    y='Wert',
    color='Wohnungsgroesse'
)

points = base.mark_circle().encode(
    opacity=alt.value(0)
).add_selection(
    highlight
).properties(
    width=700 , height=300
)
lines = base.mark_line().encode(
    size=alt.condition(~highlight, alt.value(1.5), alt.value(4))
).interactive()

points + lines
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     371
#     372         try:
# --> 373             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     374         except jsonschema.ValidationError:
#     375             dct = None
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\altair\utils\schemapi.py in <listcomp>(.0)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     371
#     372         try:
# --> 373             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     374         except jsonschema.ValidationError:
#     375             dct = None
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# C:\ProgramData\Anaconda3\envs\gis_env\lib\site-packages\altair\vegalite\v4\schema\channels.py in to_dict(self, validate, ignore, context)
#      38             elif not (type_in_shorthand or type_defined_explicitly):
#      39                 if isinstance(context.get('data', None), pd.DataFrame):
# ---> 40                     raise ValueError("{} encoding field is specified without a type; "
#      41                                      "the type cannot be inferred because it does not "
#      42                                      "match any column in the data.".format(shorthand))
#
# ValueError: KreisLang encoding field is specified without a type; the type cannot be inferred because it does not match any column in the data.
# alt.LayerChart(...)

# %%
alt.Chart(mySelection).mark_circle(size=60).encode(
    x='Wert',
    y='KreisLang',
    #color='AnzWhg',
    #color=alt.Color('EigentumsartLang', scale=alt.Scale(scheme='dark2')),
    color=alt.Color('Wert', scale=alt.Scale(scheme='greens')),
    tooltip=['Jahr', 'KreisCd', 'KreisLang', 'EigentumsartCd', 'EigentumsartLang', 'Wohnungsgroesse']
).interactive() # this makes the axes interactive: now you can zoom & pan
# Out:
# alt.Chart(...)
