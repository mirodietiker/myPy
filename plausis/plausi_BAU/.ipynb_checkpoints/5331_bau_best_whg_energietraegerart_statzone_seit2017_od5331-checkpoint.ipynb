# %% [markdown]
# **Importiere die notwendigen Packages**

# %%
# Empfehlung für Colab: Installiere alles was Du brauchst
# %pip install pandas pivottablejs numpy altair matplotlib geopandas folium

# %%
import pandas as pd
import pivottablejs
from pivottablejs import pivot_ui
import numpy as np
import altair as alt
import matplotlib.pyplot as plt
from datetime import datetime
import geopandas as gpd
import folium

# %% [markdown]
# Definiere Settings. Hier das Zahlenformat von Float-Werten (z.B. *'{:,.2f}'.format* mit Komma als Tausenderzeichen),

# %%
pd.options.display.float_format = '{:.0f}'.format
pd.set_option('display.width', 100)
pd.set_option('display.max_columns', 15)

# %% [markdown]
# Importiere einen Datensatz von der **DWH_INT** Dropzone.
#
# - Beachte dabei die Notation des Pfades...
# - Definiere mal aktuell noch keine weiteren Parameter beim Import

# %% [markdown]
# **Dataset auf INTEG Datenkatalog**: https://data.stadt-zuerich.ch/dataset/bau_best_whg_energietraegerart_statzone_seit2017_od5331
#
# (int_dwh)

# %%
# Filepath
fp = r"//szh.loc/ssz/applikationen/OGD_Dropzone/DWH/bau_best_whg_energietraegerart_statzone_seit2017_od5331/BAU533OD5331.csv"
#\\szh.loc\ssz\applikationen\OGD_Dropzone\INT_DWH\bau_best_whg_zizahl_wfl_bauperi_ea_quartier_jahr_OD5081\BAU508OD5081.csv

# Read the data
data2betested = pd.read_csv(
    fp, 
    sep=',',
   #usecols=[0,1,2,3,4,6],
   #names=['stationid','year','month','avgtemp','latitude','longitude','elevation','station','countryid','country'],
   #skiprows=1,
   # parse_dates=[0],
    parse_dates=True,
    #date_parser=lambda x: pd.to_datetime(x, format="%Y"), 
    #index_col="date_time",
    low_memory=False    
    )

# %% [markdown]
# In der Folge ein paar erste Tests:

# %%
type(data2betested)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
#  - 1) Zeige eine kurze Vorschau der importierten Daten
#  - 2) Weise die Datentypen aus
#  - 3) Zeige die Shape (Umfang) des Datensatzes an

# %%
data2betested.head(30000)
# Out:
#       Jahr  StatZoneSort      StatZoneLang  QuarSort    QuarLang  KreisSort KreisLang Bauperiode  \
# 0     2017          1101  Zähringerstrasse        11     Rathaus          1   Kreis 1  1931-1950
# 1     2017          1101  Zähringerstrasse        11     Rathaus          1   Kreis 1  1951-1970
# 2     2017          1101  Zähringerstrasse        11     Rathaus          1   Kreis 1  1971-1980
# 3     2017          1101  Zähringerstrasse        11     Rathaus          1   Kreis 1  1981-1990
# 4     2017          1101  Zähringerstrasse        11     Rathaus          1   Kreis 1  1991-2000
# ...    ...           ...               ...       ...         ...        ...       ...        ...
# 6652  2020         12304   Probsteistrasse       123  Hirzenbach         12  Kreis 12  1981-1990
# 6653  2020         12304   Probsteistrasse       123  Hirzenbach         12  Kreis 12  1991-2000
# 6654  2020         12304   Probsteistrasse       123  Hirzenbach         12  Kreis 12  2001-2010
# 6655  2020         12304   Probsteistrasse       123  Hirzenbach         12  Kreis 12   Vor 1931
# 6656  2020         12304   Probsteistrasse       123  Hirzenbach         12  Kreis 12  nach 2010
#
#       Heizöl  Gas  Holz  Wärmepumpe  Fernwärme  Andere
# 0          0    1     0           0          0       0
# 1         11    6     0           0          0       0
# 2          0   17     0           0          0       0
# 3          0    1     0           0          0       0
# 4          0    0     0           0          0       0
# ...      ...  ...   ...         ...        ...     ...
# 6652      18    0     0           5         22       0
# 6653       0    0     0           0         53       0
# 6654       0    1     0           7         40       0
# 6655       5    0     0           1          0       0
# 6656       0    0     0           0          8       0
#
# [6657 rows x 14 columns]

# %%
data2betested.dtypes
# Out:
# Jahr             int64
# StatZoneSort     int64
# StatZoneLang    object
# QuarSort         int64
# QuarLang        object
# KreisSort        int64
# KreisLang       object
# Bauperiode      object
# Heizöl           int64
# Gas              int64
# Holz             int64
# Wärmepumpe       int64
# Fernwärme        int64
# Andere           int64
# dtype: object

# %%
data2betested.shape
# Out:
# (6657, 14)

# %% [markdown]
# Beschreibe einzelne Attribute

# %%
data2betested.describe()
# Out:
#        Jahr  StatZoneSort  QuarSort  KreisSort  Heizöl  Gas  Holz  Wärmepumpe  Fernwärme  Andere
# count  6657          6657      6657       6657    6657 6657  6657        6657       6657    6657
# mean   2018          6935        69          7      34   67     1          10         22       0
# std       1          3423        34          3      75  140    17          44         81       5
# min    2017          1101        11          1       0    0     0           0          0       0
# 25%    2018          3408        34          3       0    0     0           0          0       0
# 50%    2018          7203        72          7       1   13     0           0          0       0
# 75%    2019         10102       101         10      35   69     0           4          0       0
# max    2020         12304       123         12    1123 1411   512        1095       1090     191

# %% [markdown]
# Wie viele Nullwerte gibt es im Datensatz?

# %%
data2betested.isnull().sum()
# Out:
# Jahr            0
# StatZoneSort    0
# StatZoneLang    0
# QuarSort        0
# QuarLang        0
# KreisSort       0
# KreisLang       0
# Bauperiode      0
# Heizöl          0
# Gas             0
# Holz            0
# Wärmepumpe      0
# Fernwärme       0
# Andere          0
# dtype: int64

# %% [markdown]
# In gewissen Datensätzen kommen noch die Zeilen `Jahr` anstatt `StichDatJahr` vor. Diese werden hier für solche Fälle ergänzt.

# %%
if set(['Jahr']).issubset(data2betested.columns):
    data2betested['StichtagDatJahr'] = data2betested['Jahr']

# %% [markdown]
# Wandle die Spalte Jahr von Int zu **Datetime** um. Dies wird in den meisten Grafiken so benötigt.

# %%
data2betested['StichtagDatJahr']=pd.to_datetime(data2betested['StichtagDatJahr'], format='%Y')
#data2betested['Jahr']=pd.to_datetime(data2betested['Jahr'], format='%Y')
#data2betested['Jahr']=pd.to_datetime(data2betested['Jahr'], format='%Y')
#TO DO --> setze das Datum auf den 31.12. der Jahres.
#test=data2betested[['StichtagDatJahr']].date().replace(month=12, day=31)

data2betested
# Out:
#            Jahr  StatZoneSort      StatZoneLang  QuarSort    QuarLang  KreisSort KreisLang  \
# 0    2017-01-01          1101  Zähringerstrasse        11     Rathaus          1   Kreis 1
# 1    2017-01-01          1101  Zähringerstrasse        11     Rathaus          1   Kreis 1
# 2    2017-01-01          1101  Zähringerstrasse        11     Rathaus          1   Kreis 1
# 3    2017-01-01          1101  Zähringerstrasse        11     Rathaus          1   Kreis 1
# 4    2017-01-01          1101  Zähringerstrasse        11     Rathaus          1   Kreis 1
# ...         ...           ...               ...       ...         ...        ...       ...
# 6652 2020-01-01         12304   Probsteistrasse       123  Hirzenbach         12  Kreis 12
# 6653 2020-01-01         12304   Probsteistrasse       123  Hirzenbach         12  Kreis 12
# 6654 2020-01-01         12304   Probsteistrasse       123  Hirzenbach         12  Kreis 12
# 6655 2020-01-01         12304   Probsteistrasse       123  Hirzenbach         12  Kreis 12
# 6656 2020-01-01         12304   Probsteistrasse       123  Hirzenbach         12  Kreis 12
#
#      Bauperiode  Heizöl  Gas  Holz  Wärmepumpe  Fernwärme  Andere StichtagDatJahr
# 0     1931-1950       0    1     0           0          0       0      2017-01-01
# 1     1951-1970      11    6     0           0          0       0      2017-01-01
# 2     1971-1980       0   17     0           0          0       0      2017-01-01
# 3     1981-1990       0    1     0           0          0       0      2017-01-01
# 4     1991-2000       0    0     0           0          0       0      2017-01-01
# ...         ...     ...  ...   ...         ...        ...     ...             ...
# 6652  1981-1990      18    0     0           5         22       0      2020-01-01
# 6653  1991-2000       0    0     0           0         53       0      2020-01-01
# 6654  2001-2010       0    1     0           7         40       0      2020-01-01
# 6655   Vor 1931       5    0     0           1          0       0      2020-01-01
# 6656  nach 2010       0    0     0           0          8       0      2020-01-01
#
# [6657 rows x 15 columns]

# %% [markdown]
# Bereite die Daten für die Grafik unten vor

# %%
Jahre = data2betested.groupby("StichtagDatJahr")
len(Jahre)
# Out:
# 4

# %%
for key, group in Jahre:
    print(key, len(group))
# Out:
# 2017-01-01 00:00:00 1664
# 2018-01-01 00:00:00 1666
# 2019-01-01 00:00:00 1664
# 2020-01-01 00:00:00 1663

# %%
myJahr = "2020-01-01"
aktuellesJahr=Jahre.get_group(myJahr)   
aktuellesJahr.head(3)
# Out:
#            Jahr  StatZoneSort      StatZoneLang  QuarSort QuarLang  KreisSort KreisLang  \
# 4994 2020-01-01          1101  Zähringerstrasse        11  Rathaus          1   Kreis 1
# 4995 2020-01-01          1101  Zähringerstrasse        11  Rathaus          1   Kreis 1
# 4996 2020-01-01          1101  Zähringerstrasse        11  Rathaus          1   Kreis 1
#
#      Bauperiode  Heizöl  Gas  Holz  Wärmepumpe  Fernwärme  Andere StichtagDatJahr
# 4994  1931-1950       0    1     0           0          0       0      2020-01-01
# 4995  1951-1970      11    6     0           0          0       0      2020-01-01
# 4996  1971-1980       0   17     0           0          0       0      2020-01-01

# %% [markdown]
# **Selektionen und Aggregationen**
#
# Check this [Doku](https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/)

# %%
#test = data2betested.groupby(['StichtagDatJahr', 'AlterV20Kurz'])[['AnzBestWir']].agg()

# produces Pandas Series
    #data2betested.groupby(['StichtagDatJahr', 'KonOGDSort'])['AnzBestWir'].sum()
# Produces Pandas DataFrame
    #data2betested.groupby(['StichtagDatJahr', 'KonOGDSort'])[['AnzBestWir']].sum()
    
test = data2betested.groupby(
   ['StichtagDatJahr', 'QuarSort', 'QuarLang', 'Bauperiode']
).agg(
    {
        'Heizöl':(sum),     # Sum --> (sum)
        'Gas': (sum),   
        'Holz': (sum),  
        'Wärmepumpe': (sum),
        'Fernwärme':(sum),
        'Andere': (sum)
    }
)
test.head(1000)
# Out:
#                                                Heizöl   Gas  Holz  Wärmepumpe  Fernwärme  Andere
# StichtagDatJahr QuarSort QuarLang  Bauperiode
# 2017-01-01      11       Rathaus   1931-1950        0    18     6           0          0       0
#                                    1951-1970       47   206     0           0          0       0
#                                    1971-1980        8    48     0           0          0       0
#                                    1981-1990        0    18     0           0          0       0
#                                    1991-2000        0     0     0           0          6       0
# ...                                               ...   ...   ...         ...        ...     ...
# 2020-01-01      82       Mühlebach 1981-1990       15   161     0           0          0       0
#                                    1991-2000        0   208     0           9          0       0
#                                    2001-2010        1    20     0          89          4       0
#                                    Vor 1931       271  1221     0          41          0       1
#                                    nach 2010        0    32    10         171          0       0
#
# [1000 rows x 6 columns]

# %% [markdown]
# **Einfache Visualisierungen zur Plausi**

# %% [markdown]
# Exploriere die Daten mit Pivottable.JS

# %%
from pivottablejs import pivot_ui

pivot_ui(data2betested)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Liniendiagramm
# [Link zur Doku](https://altair-viz.github.io/gallery/multiline_highlight.html)

# %%
#mySelection = aktuellesJahr[(data2betested.QuarSort=31)]
mySelection = aktuellesJahr.groupby(['StichtagDatJahr', 'Bauperiode'])[['Heizöl','Gas','Fernwärme','Wärmepumpe', 'Andere']].sum()
mySelection.head(10)
# Out:
#                             Heizöl    Gas  Fernwärme  Wärmepumpe  Andere
# StichtagDatJahr Bauperiode
# 2020-01-01      1931-1950    11623  18412       4723        1389      27
#                 1951-1970    20995  20845       9356        1145       9
#                 1971-1980     6839   9364       2757         816      64
#                 1981-1990     1776   7906       1717         298      14
#                 1991-2000      484   5716       2015         147      25
#                 2001-2010      152   4860       5922        1759     216
#                 Vor 1931     12048  44018       2621        1724     256
#                 nach 2010       43   2310       9490       12647      70

# %%
mySelection = aktuellesJahr[["StichtagDatJahr","QuarLang", "KreisLang","Bauperiode","Wärmepumpe"]]
mySelection
# Out:
#      StichtagDatJahr    QuarLang KreisLang Bauperiode  Wärmepumpe
# 4994      2020-01-01     Rathaus   Kreis 1  1931-1950           0
# 4995      2020-01-01     Rathaus   Kreis 1  1951-1970           0
# 4996      2020-01-01     Rathaus   Kreis 1  1971-1980           0
# 4997      2020-01-01     Rathaus   Kreis 1  1981-1990           0
# 4998      2020-01-01     Rathaus   Kreis 1  1991-2000           0
# ...              ...         ...       ...        ...         ...
# 6652      2020-01-01  Hirzenbach  Kreis 12  1981-1990           5
# 6653      2020-01-01  Hirzenbach  Kreis 12  1991-2000           0
# 6654      2020-01-01  Hirzenbach  Kreis 12  2001-2010           7
# 6655      2020-01-01  Hirzenbach  Kreis 12   Vor 1931           1
# 6656      2020-01-01  Hirzenbach  Kreis 12  nach 2010           0
#
# [1663 rows x 5 columns]

# %%
agg_mySelection = mySelection.groupby(
   ['StichtagDatJahr', 'KreisLang']
).agg(
    {
         #'Bauperiode"':(sum,min, max),     # Sum --> (sum)
         'Wärmepumpe': (sum, min, max)
    }
)
agg_mySelection
# Out:
#                           Wärmepumpe
#                                  sum min   max
# StichtagDatJahr KreisLang
# 2020-01-01      Kreis 1           47   0    13
#                 Kreis 10        2196   0   282
#                 Kreis 11        2894   0   395
#                 Kreis 12         333   0    72
#                 Kreis 2         3194   0   692
#                 Kreis 3         1721   0   358
#                 Kreis 4          679   0   181
#                 Kreis 5           95   0    47
#                 Kreis 6         1141   0   146
#                 Kreis 7         1943   0   257
#                 Kreis 8          978   0   133
#                 Kreis 9         4704   0  1095

# %%
mySelection = aktuellesJahr[(aktuellesJahr.KreisSort>10) & (aktuellesJahr.Wärmepumpe>0)]

mySelection.head()
# Out:
#            Jahr  StatZoneSort StatZoneLang  QuarSort   QuarLang  KreisSort KreisLang Bauperiode  \
# 6364 2020-01-01         11101    Mühlacker       111  Affoltern         11  Kreis 11  1931-1950
# 6365 2020-01-01         11101    Mühlacker       111  Affoltern         11  Kreis 11  1951-1970
# 6367 2020-01-01         11101    Mühlacker       111  Affoltern         11  Kreis 11  1981-1990
# 6368 2020-01-01         11101    Mühlacker       111  Affoltern         11  Kreis 11  1991-2000
# 6369 2020-01-01         11101    Mühlacker       111  Affoltern         11  Kreis 11  2001-2010
#
#       Heizöl  Gas  Holz  Wärmepumpe  Fernwärme  Andere StichtagDatJahr
# 6364       8    0     0           3          0       0      2020-01-01
# 6365       6   17     0           1          0       0      2020-01-01
# 6367       3   10     1           1          0       0      2020-01-01
# 6368       0   47     0           2          0       0      2020-01-01
# 6369       0  475   325          29          0       0      2020-01-01

# %%
# df_statzonen = df_statzonen[(df_statzonen.knr>0) & (df_statzonen.qname!="Hirslanden")]

highlight = alt.selection(type='single', on='mouseover',
                          fields=['QuarLang'], nearest=True)
#x='date:StichtagDatJahr',
base = alt.Chart(mySelection).encode(
    x='Bauperiode',
    y='Wärmepumpe',
    color='QuarLang'
)

points = base.mark_circle().encode(
    opacity=alt.value(0)
).add_selection(
    highlight
).properties(
    width=700 , height=300
)
lines = base.mark_line().encode(
    size=alt.condition(~highlight, alt.value(1.5), alt.value(4))
).interactive()

points + lines
# Out:
# alt.LayerChart(...)

# %%
alt.Chart(mySelection).mark_circle(size=60).encode(
    x='QuarLang',
    y='Bauperiode',
    #color='AnzWhg',
    #color=alt.Color('AnzNat', scale=alt.Scale(scheme='dark2')),
    color=alt.Color('Wärmepumpe', scale=alt.Scale(scheme='Reds')),
    tooltip=['QuarLang','StichtagDatJahr','Bauperiode','Wärmepumpe']
).interactive() # this makes the axes interactive: now you can zoom & pan
# Out:
# alt.Chart(...)

# %% [markdown]
# **Test: Choroplethenkarte**
# Importiere die Geodaten als GeoJSON

# %%
# Read abt. Geopandas https://geopandas.org/docs/user_guide/io.html
# Wenn die Daten lokal agelegt sind, dann kannst Du folgendes machen:
##input_stadtquartiere = r"//szh.loc/ssz/data/GIS/Daten/Vektor/_aktuell/stzh.adm_statistische_quartiere_map.json"
##df_stadtquartiere = gpd.read_file(input_stadtquartiere)
##df_stadtquartiere.head(2)
#df_stadtkreise.dtypes

geojson_url = "https://www.ogd.stadt-zuerich.ch/wfs/geoportal/Statistische_Quartiere?service=WFS&version=1.1.0&request=GetFeature&outputFormat=GeoJSON&typename=adm_statistische_quartiere_map"
df_adm_statistische_quartiere_map = gpd.read_file(geojson_url)

df_adm_statistische_quartiere_map.head(5)
# Out:
#                                  id    kname  knr  objectid objid       qname  qnr  \
# 0  adm_statistische_quartiere_map.1  Kreis 7    7         1    34  Hirslanden   73
# 1  adm_statistische_quartiere_map.2  Kreis 8    8         2    33     Weinegg   83
# 2  adm_statistische_quartiere_map.3  Kreis 8    8         3    32   Mühlebach   82
# 3  adm_statistische_quartiere_map.4  Kreis 8    8         4    31     Seefeld   81
# 4  adm_statistische_quartiere_map.7  Kreis 4    4         7    16        Werd   41
#
#                                             geometry
# 0  POLYGON ((8.55670 47.36406, 8.55682 47.36410, ...
# 1  POLYGON ((8.55670 47.36405, 8.55672 47.36403, ...
# 2  POLYGON ((8.55423 47.36456, 8.55426 47.36452, ...
# 3  POLYGON ((8.54795 47.36500, 8.54805 47.36489, ...
# 4  POLYGON ((8.53300 47.37394, 8.53299 47.37392, ...

# %% [markdown]
# Joine die importierten statistischen Daten des aktuellen Jahres zum Geodatensatz:
#
# *Siehe dazu Doku zu [Geopandas](https://geopandas.org/docs/user_guide/mergingdata.html)*

# %%
aktuellesJahr.head()
# Out:
#            Jahr  StatZoneSort      StatZoneLang  QuarSort QuarLang  KreisSort KreisLang  \
# 4994 2020-01-01          1101  Zähringerstrasse        11  Rathaus          1   Kreis 1
# 4995 2020-01-01          1101  Zähringerstrasse        11  Rathaus          1   Kreis 1
# 4996 2020-01-01          1101  Zähringerstrasse        11  Rathaus          1   Kreis 1
# 4997 2020-01-01          1101  Zähringerstrasse        11  Rathaus          1   Kreis 1
# 4998 2020-01-01          1101  Zähringerstrasse        11  Rathaus          1   Kreis 1
#
#      Bauperiode  Heizöl  Gas  Holz  Wärmepumpe  Fernwärme  Andere StichtagDatJahr
# 4994  1931-1950       0    1     0           0          0       0      2020-01-01
# 4995  1951-1970      11    6     0           0          0       0      2020-01-01
# 4996  1971-1980       0   17     0           0          0       0      2020-01-01
# 4997  1981-1990       0    1     0           0          0       0      2020-01-01
# 4998  1991-2000       0    0     0           0          0       0      2020-01-01

# %%
stats_agg_quartiere=aktuellesJahr.groupby(['StichtagDatJahr', 'QuarSort'])[['Wärmepumpe','Fernwärme','Gas', 'Heizöl','Andere']].sum()
#test = data2betested.groupby(['StichtagDatJahr', 'AlterV20Kurz'])[['AnzBestWir']].agg()
stats_agg_quartiere.head()
#test = data2betested.groupby(['StichtagDatJahr', 'AlterV20Kurz'])[['AnzBestWir']].agg()
# Out:
#                           Wärmepumpe  Fernwärme   Gas  Heizöl  Andere
# StichtagDatJahr QuarSort
# 2020-01-01      11                26          9  2067     164      29
#                 12                 7         72   197      49       4
#                 13                12          2   757      57      10
#                 14                 2          0   330      59       0
#                 21              2456         79  4789    2520      20

# %%
# Rename attribute stznr to StatZoneSort, so the IDs have the same name

stadtquartiere_shapes = df_adm_statistische_quartiere_map[['geometry', 'qnr', 'qname', 'knr']].rename(columns={'qnr': 'QuarSort'})

# Merge with `merge` method on shared variable (stznr und StatZoneSort):
stadtquartiere_shapes_joined = stadtquartiere_shapes.merge(stats_agg_quartiere, on='QuarSort')

stadtquartiere_shapes_joined.head(3)
# Out:
#                                             geometry  QuarSort       qname  knr  Wärmepumpe  \
# 0  POLYGON ((8.55670 47.36406, 8.55682 47.36410, ...        73  Hirslanden    7         247
# 1  POLYGON ((8.55670 47.36405, 8.55672 47.36403, ...        83     Weinegg    8         278
# 2  POLYGON ((8.55423 47.36456, 8.55426 47.36452, ...        82   Mühlebach    8         371
#
#    Fernwärme   Gas  Heizöl  Andere
# 0         15  2753    1081      10
# 1          0  1820     755      22
# 2          4  2765     774       2

# %%
# Plot by StatQuartiere

stadtquartiere_shapes_joined.plot(column='Wärmepumpe', cmap='viridis', scheme='natural_breaks', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html

stadtquartiere_shapes_joined.plot(column='Fernwärme', cmap='plasma', scheme='quantiles', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html
stadtquartiere_shapes_joined.plot(column='Gas', cmap='cool', scheme='fisherjenks', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html

stadtquartiere_shapes_joined.plot(column='Heizöl', cmap='viridis', scheme='natural_breaks', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1, 1)
stadtquartiere_shapes_joined.plot(column='Wärmepumpe', ax=ax, legend=True, legend_kwds={'label': "Anzahl WHG mit Wärmepumpen",'orientation': "horizontal"})
# Out:
# <AxesSubplot:>

# %% [markdown]
# Noch zu prüfen, folgendes schöne Beispiel: https://docs.bokeh.org/en/latest/docs/user_guide/interaction/legends.html
#
# Konkrete Beispiele von Bookeh in Jupyter NB: https://docs.bokeh.org/en/latest/docs/user_guide/jupyter.html

# %% [markdown]
# **Sharepoint als gecheckt markieren!**

# %% [markdown]
# Record auf Sharepoint: **[Link](http://kollaboration.intranet.stzh.ch/orga/ssz-produkte/Lists/SASA_Outputs/EditForm.aspx?ID=157&Source=%2Forga%2Fssz%2Dprodukte%2FLists%2FSASA%5FOutputs)**
