# %% [markdown]
# **Importiere die notwendigen Packages**

# %%
# Empfehlung für Colab: Installiere alles was Du brauchst
# %pip install pandas pivottablejs numpy altair matplotlib geopandas folium

# %%
import pandas as pd
import pivottablejs
from pivottablejs import pivot_ui
import numpy as np
import altair as alt
import matplotlib.pyplot as plt
from datetime import datetime
import geopandas as gpd
import folium

# %% [markdown]
# Definiere Settings. Hier das Zahlenformat von Float-Werten (z.B. *'{:,.2f}'.format* mit Komma als Tausenderzeichen),

# %%
pd.options.display.float_format = '{:.0f}'.format
pd.set_option('display.width', 100)
pd.set_option('display.max_columns', 15)

# %% [markdown]
# Importiere einen Datensatz von der **DWH_INT** Dropzone.
#
# - Beachte dabei die Notation des Pfades...
# - Definiere mal aktuell noch keine weiteren Parameter beim Import

# %% [markdown]
# **Dataset auf INTEG Datenkatalog**: https://data.integ.stadt-zuerich.ch/dataset/int_dwh_bau_best_whg_zizahl_wfl_bauperi_ea_quartier_jahr_od5081
#
# (int_dwh)

# %%
# Filepath
fp = r"//szh.loc/ssz/applikationen/OGD_Dropzone/INT_DWH/bau_best_whg_zizahl_wfl_bauperi_ea_quartier_jahr_OD5081\BAU508OD5081.csv"
#\\szh.loc\ssz\applikationen\OGD_Dropzone\INT_DWH\bau_best_whg_zizahl_wfl_bauperi_ea_quartier_jahr_OD5081\BAU508OD5081.csv

# Read the data
data2betested = pd.read_csv(
    fp, 
    sep=',',
   #usecols=[0,1,2,3,4,6],
   #names=['stationid','year','month','avgtemp','latitude','longitude','elevation','station','countryid','country'],
   #skiprows=1,
   # parse_dates=[0],
    parse_dates=True,
    #date_parser=lambda x: pd.to_datetime(x, format="%Y"), 
    #index_col="date_time",
    low_memory=False    
    )

# %% [markdown]
# In der Folge ein paar erste Tests:

# %%
type(data2betested)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
#  - 1) Zeige eine kurze Vorschau der importierten Daten
#  - 2) Weise die Datentypen aus
#  - 3) Zeige die Shape (Umfang) des Datensatzes an

# %%
data2betested.head(30000)
# Out:
#        StichtagDatJahr  QuarSort   QuarLang  KreisSort KreisLang  ZimmerSort ZimmerLang  \
# 0                 2008        11    Rathaus          1   Kreis 1           1   1 Zimmer
# 1                 2008        11    Rathaus          1   Kreis 1           1   1 Zimmer
# 2                 2008        11    Rathaus          1   Kreis 1           1   1 Zimmer
# 3                 2008        11    Rathaus          1   Kreis 1           1   1 Zimmer
# 4                 2008        11    Rathaus          1   Kreis 1           1   1 Zimmer
# ...                ...       ...        ...        ...       ...         ...        ...
# 29995             2012       111  Affoltern         11  Kreis 11           4   4 Zimmer
# 29996             2012       111  Affoltern         11  Kreis 11           4   4 Zimmer
# 29997             2012       111  Affoltern         11  Kreis 11           4   4 Zimmer
# 29998             2012       111  Affoltern         11  Kreis 11           4   4 Zimmer
# 29999             2012       111  Affoltern         11  Kreis 11           4   4 Zimmer
#
#        MietwohnungSort MietwohnungLang  BauperiodeSort BauperiodeLang  EigGruSort  \
# 0                  NaN       Unbekannt               1       Vor 1893           1
# 1                  NaN       Unbekannt               1       Vor 1893           3
# 2                  NaN       Unbekannt               1       Vor 1893           4
# 3                  NaN       Unbekannt               1       Vor 1893           5
# 4                  NaN       Unbekannt               2    1893 - 1930           3
# ...                ...             ...             ...            ...         ...
# 29995              NaN       Unbekannt               8    1981 - 1990           2
# 29996              NaN       Unbekannt               8    1981 - 1990           3
# 29997              NaN       Unbekannt               8    1981 - 1990           4
# 29998              NaN       Unbekannt               8    1981 - 1990           5
# 29999              NaN       Unbekannt               9    1991 - 2000           2
#
#                     EigGruLang  AnzWhg  Wohnungsfl
# 0             Öffentliche Hand     102        3622
# 1       Übrige private Gesell.      84        2124
# 2          Natürliche Personen     264        7978
# 3         Im Stockwerkeigentum      24         556
# 4       Übrige private Gesell.      15         303
# ...                        ...     ...         ...
# 29995  Wohnbaugenossenschaften      27        1920
# 29996   Übrige private Gesell.     195       20249
# 29997      Natürliche Personen      29        3155
# 29998     Im Stockwerkeigentum       9        1072
# 29999  Wohnbaugenossenschaften      43        4578
#
# [30000 rows x 15 columns]

# %%
data2betested.dtypes
# Out:
# StichtagDatJahr      int64
# QuarSort             int64
# QuarLang            object
# KreisSort            int64
# KreisLang           object
# ZimmerSort           int64
# ZimmerLang          object
# MietwohnungSort    float64
# MietwohnungLang     object
# BauperiodeSort       int64
# BauperiodeLang      object
# EigGruSort           int64
# EigGruLang          object
# AnzWhg               int64
# Wohnungsfl           int64
# dtype: object

# %%
data2betested.shape
# Out:
# (96356, 15)

# %% [markdown]
# Beschreibe einzelne Attribute

# %%
data2betested.describe()
# Out:
#        StichtagDatJahr  QuarSort  KreisSort  ZimmerSort  MietwohnungSort  BauperiodeSort  \
# count            96356     96356      96356       96356            58826           96356
# mean              2015        71          7           4                1               5
# std                  4        34          3           2                0               3
# min               2008        11          1           1                0               1
# 25%               2011        41          4           2                0               3
# 50%               2015        73          7           4                1               5
# 75%               2018       101         10           5                1               8
# max               2020       123         12           8                1              11
#
#        EigGruSort  AnzWhg  Wohnungsfl
# count       96356   96356       96356
# mean            3      29        2264
# std             1      64        4784
# min             1       1           7
# 25%             3       2         234
# 50%             4       7         695
# 75%             4      26        2085
# max             5    1474      107074

# %% [markdown]
# Wie viele Nullwerte gibt es im Datensatz?

# %%
data2betested.isnull().sum()
# Out:
# StichtagDatJahr        0
# QuarSort               0
# QuarLang               0
# KreisSort              0
# KreisLang              0
# ZimmerSort             0
# ZimmerLang             0
# MietwohnungSort    37530
# MietwohnungLang        0
# BauperiodeSort         0
# BauperiodeLang         0
# EigGruSort             0
# EigGruLang             0
# AnzWhg                 0
# Wohnungsfl             0
# dtype: int64

# %% [markdown]
# Wandle die Spalte Jahr von Int zu **Datetime** um. Dies wird in den meisten Grafiken so benötigt.

# %%
data2betested['StichtagDatJahr']=pd.to_datetime(data2betested['StichtagDatJahr'], format='%Y')
#data2betested['Jahr']=pd.to_datetime(data2betested['Jahr'], format='%Y')
#TO DO --> setze das Datum auf den 31.12. der Jahres.
#test=data2betested[['StichtagDatJahr']].date().replace(month=12, day=31)

data2betested
# Out:
#       StichtagDatJahr  QuarSort    QuarLang  KreisSort KreisLang  ZimmerSort   ZimmerLang  \
# 0          2008-01-01        11     Rathaus          1   Kreis 1           1     1 Zimmer
# 1          2008-01-01        11     Rathaus          1   Kreis 1           1     1 Zimmer
# 2          2008-01-01        11     Rathaus          1   Kreis 1           1     1 Zimmer
# 3          2008-01-01        11     Rathaus          1   Kreis 1           1     1 Zimmer
# 4          2008-01-01        11     Rathaus          1   Kreis 1           1     1 Zimmer
# ...               ...       ...         ...        ...       ...         ...          ...
# 96351      2020-01-01       123  Hirzenbach         12  Kreis 12           7     7 Zimmer
# 96352      2020-01-01       123  Hirzenbach         12  Kreis 12           7     7 Zimmer
# 96353      2020-01-01       123  Hirzenbach         12  Kreis 12           7     7 Zimmer
# 96354      2020-01-01       123  Hirzenbach         12  Kreis 12           8  Ab 8 Zimmer
# 96355      2020-01-01       123  Hirzenbach         12  Kreis 12           8  Ab 8 Zimmer
#
#        MietwohnungSort MietwohnungLang  BauperiodeSort BauperiodeLang  EigGruSort  \
# 0                  NaN       Unbekannt               1       Vor 1893           1
# 1                  NaN       Unbekannt               1       Vor 1893           3
# 2                  NaN       Unbekannt               1       Vor 1893           4
# 3                  NaN       Unbekannt               1       Vor 1893           5
# 4                  NaN       Unbekannt               2    1893 - 1930           3
# ...                ...             ...             ...            ...         ...
# 96351                1              Ja               5    1951 - 1960           4
# 96352                1              Ja               9    1991 - 2000           1
# 96353                1              Ja              11    2011 - 2020           3
# 96354                1              Ja               5    1951 - 1960           3
# 96355                1              Ja               7    1971 - 1980           3
#
#                    EigGruLang  AnzWhg  Wohnungsfl
# 0            Öffentliche Hand     102        3622
# 1      Übrige private Gesell.      84        2124
# 2         Natürliche Personen     264        7978
# 3        Im Stockwerkeigentum      24         556
# 4      Übrige private Gesell.      15         303
# ...                       ...     ...         ...
# 96351     Natürliche Personen       1         150
# 96352        Öffentliche Hand       1         189
# 96353  Übrige private Gesell.       3         915
# 96354  Übrige private Gesell.       1         130
# 96355  Übrige private Gesell.       1         146
#
# [96356 rows x 15 columns]

# %% [markdown]
# Bereite die Daten für die Grafik unten vor

# %%
Jahre = data2betested.groupby("StichtagDatJahr")
len(Jahre)
# Out:
# 13

# %%
for key, group in Jahre:
    print(key, len(group))
# Out:
# 2008-01-01 00:00:00 6049
# 2009-01-01 00:00:00 6085
# 2010-01-01 00:00:00 6125
# 2011-01-01 00:00:00 6359
# 2012-01-01 00:00:00 6437
# 2013-01-01 00:00:00 6475
# 2014-01-01 00:00:00 8209
# 2015-01-01 00:00:00 8302
# 2016-01-01 00:00:00 8391
# 2017-01-01 00:00:00 8454
# 2018-01-01 00:00:00 8468
# 2019-01-01 00:00:00 8479
# 2020-01-01 00:00:00 8523

# %%
myJahr = "2020-01-01"
aktuellesJahr=Jahre.get_group(myJahr)   
aktuellesJahr.head(3)
# Out:
#       StichtagDatJahr  QuarSort QuarLang  KreisSort KreisLang  ZimmerSort ZimmerLang  \
# 87833      2020-01-01        11  Rathaus          1   Kreis 1           1   1 Zimmer
# 87834      2020-01-01        11  Rathaus          1   Kreis 1           1   1 Zimmer
# 87835      2020-01-01        11  Rathaus          1   Kreis 1           1   1 Zimmer
#
#        MietwohnungSort MietwohnungLang  BauperiodeSort BauperiodeLang  EigGruSort  \
# 87833                0            Nein               1       Vor 1893           5
# 87834                0            Nein               7    1971 - 1980           5
# 87835                1              Ja               1       Vor 1893           1
#
#                  EigGruLang  AnzWhg  Wohnungsfl
# 87833  Im Stockwerkeigentum       2          64
# 87834  Im Stockwerkeigentum       7         175
# 87835      Öffentliche Hand     119        4355

# %% [markdown]
# **Selektionen und Aggregationen**
#
# Check this [Doku](https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/)

# %%
#test = data2betested.groupby(['StichtagDatJahr', 'AlterV20Kurz'])[['AnzBestWir']].agg()

# produces Pandas Series
    #data2betested.groupby(['StichtagDatJahr', 'KonOGDSort'])['AnzBestWir'].sum()
# Produces Pandas DataFrame
    #data2betested.groupby(['StichtagDatJahr', 'KonOGDSort'])[['AnzBestWir']].sum()
    
test = data2betested.groupby(
   ['StichtagDatJahr', 'QuarSort', 'QuarLang']
).agg(
    {
         'AnzWhg':(sum),     # Sum --> (sum)
         'EigGruLang': 'last',   
         'Wohnungsfl': 'max'  # get the first date per group
    }
)
test.head(10)
# Out:
#                                        AnzWhg              EigGruLang  Wohnungsfl
# StichtagDatJahr QuarSort QuarLang
# 2008-01-01      11       Rathaus         2312        Öffentliche Hand       16689
#                 12       Hochschulen      334  Übrige private Gesell.        1869
#                 13       Lindenhof        842  Übrige private Gesell.        6195
#                 14       City             451  Übrige private Gesell.        3503
#                 21       Wollishofen     8671     Natürliche Personen       30567
#                 23       Leimbach        2429     Natürliche Personen       12080
#                 24       Enge            5022    Im Stockwerkeigentum       27460
#                 31       Alt-Wiedikon    9230     Natürliche Personen       67909
#                 33       Friesenberg     4328    Im Stockwerkeigentum       27284
#                 34       Sihlfeld       11846        Öffentliche Hand      107074

# %%
#In den Rohdaten gibt es viele Werte, wo MietwohnungSort leer ist. Was geschieht damit in der Aggregation?      
test2= data2betested[['StichtagDatJahr','MietwohnungSort', 'MietwohnungLang','AnzWhg']]
test2= data2betested.groupby(['StichtagDatJahr','MietwohnungSort', 'MietwohnungLang'])[['AnzWhg']].sum()  
test2.head(100000)
# Out:
#                                                  AnzWhg
# StichtagDatJahr MietwohnungSort MietwohnungLang
# 2014-01-01      0               Nein              19036
#                 1               Ja               196441
# 2015-01-01      0               Nein              19139
#                 1               Ja               198918
# 2016-01-01      0               Nein              19058
#                 1               Ja               200892
# 2017-01-01      0               Nein              18892
#                 1               Ja               203357
# 2018-01-01      0               Nein              19038
#                 1               Ja               206256
# 2019-01-01      0               Nein              18759
#                 1               Ja               208377
# 2020-01-01      0               Nein              18469
#                 1               Ja               210348

# %% [markdown]
# **Einfache Visualisierungen zur Plausi**

# %% [markdown]
# Exploriere die Daten mit Pivottable.JS

# %%
from pivottablejs import pivot_ui

pivot_ui(data2betested)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Liniendiagramm
# [Link zur Doku](https://altair-viz.github.io/gallery/multiline_highlight.html)

# %%
#mySelection = aktuellesJahr[(data2betested.QuarSort=31)]
mySelection = aktuellesJahr.groupby(['StichtagDatJahr', 'EigGruLang'])['AnzWhg'].sum()
mySelection.head()
# Out:
# StichtagDatJahr  EigGruLang
# 2020-01-01       Im Stockwerkeigentum       21581
#                  Natürliche Personen        77674
#                  Wohnbaugenossenschaften    41256
#                  Öffentliche Hand           15578
#                  Übrige private Gesell.     72728
# Name: AnzWhg, dtype: int64

# %%
mySelection = aktuellesJahr[["StichtagDatJahr","QuarLang","EigGruLang","AnzWhg", "Wohnungsfl"]]
mySelection
# Out:
#       StichtagDatJahr    QuarLang              EigGruLang  AnzWhg  Wohnungsfl
# 87833      2020-01-01     Rathaus    Im Stockwerkeigentum       2          64
# 87834      2020-01-01     Rathaus    Im Stockwerkeigentum       7         175
# 87835      2020-01-01     Rathaus        Öffentliche Hand     119        4355
# 87836      2020-01-01     Rathaus  Übrige private Gesell.     114        3198
# 87837      2020-01-01     Rathaus     Natürliche Personen     178        5688
# ...               ...         ...                     ...     ...         ...
# 96351      2020-01-01  Hirzenbach     Natürliche Personen       1         150
# 96352      2020-01-01  Hirzenbach        Öffentliche Hand       1         189
# 96353      2020-01-01  Hirzenbach  Übrige private Gesell.       3         915
# 96354      2020-01-01  Hirzenbach  Übrige private Gesell.       1         130
# 96355      2020-01-01  Hirzenbach  Übrige private Gesell.       1         146
#
# [8523 rows x 5 columns]

# %%
agg_mySelection = mySelection.groupby(
   ['StichtagDatJahr', 'QuarLang']
).agg(
    {
         'AnzWhg':(sum,min, max),     # Sum --> (sum)
         'Wohnungsfl': (sum, min, max)
    }
)
agg_mySelection
# Out:
#                                      AnzWhg           Wohnungsfl
#                                         sum min   max        sum min    max
# StichtagDatJahr QuarLang
# 2020-01-01      Affoltern             12061   1   587     997619  25  35320
#                 Albisrieden           11794   1   597     926139  25  44985
#                 Alt-Wiedikon          10294   1   845     744736  29  59529
#                 Altstetten            18059   1   684    1333029  34  44147
#                 City                    392   1    48      37195  44   3824
#                 Enge                   5391   1   258     485330  31  22574
#                 Escher Wyss            3261   1   318     321623  16  32288
#                 Fluntern               4362   1   108     472859  28  22778
#                 Friesenberg            4529   1   300     362934  29  24148
#                 Gewerbeschule          5250   1   496     367109   7  36022
#                 Hard                   7062   1   548     465603  22  39488
#                 Hirslanden             4127   1   429     353229  25  37516
#                 Hirzenbach             6211   1   590     449857  29  38832
#                 Hochschulen             329   1    31      28251  50   1455
#                 Hottingen              6126   1   322     579173  20  33213
#                 Höngg                 12214   1   422    1051423  25  30071
#                 Langstrasse            7303   1   644     485841  25  46870
#                 Leimbach               2653   1   149     227514  14  12082
#                 Lindenhof               842   1   101      62751  25   5404
#                 Mühlebach              3926   1   183     310479  25  12975
#                 Oberstrass             5710   1   452     501597  29  47923
#                 Oerlikon              12526   1   520     949711  29  38547
#                 Rathaus                2317   1   262     157636  40  16893
#                 Saatlen                3568   1   289     304932  30  30914
#                 Schwamendingen-Mitte   5958   1   427     414640  21  29441
#                 Seebach               13236   1   488    1013339  25  43010
#                 Seefeld                3639   1   359     280483  29  27596
#                 Sihlfeld              12514   1  1304     851077  28  94406
#                 Unterstrass           12799   1   779     986510  20  60792
#                 Weinegg                2876   1   126     251744  25   9880
#                 Werd                   2423   1   178     174303  25  12708
#                 Wipkingen              9173   1   862     655802  25  62260
#                 Witikon                5941   1   267     565609  20  21174
#                 Wollishofen            9951   1   315     822501  25  23621

# %%
mySelection = aktuellesJahr[(aktuellesJahr.KreisSort>11) & (aktuellesJahr.ZimmerSort>2)]

mySelection.head()
# Out:
#       StichtagDatJahr  QuarSort QuarLang  KreisSort KreisLang  ZimmerSort ZimmerLang  \
# 95824      2020-01-01       121  Saatlen         12  Kreis 12           3   3 Zimmer
# 95825      2020-01-01       121  Saatlen         12  Kreis 12           3   3 Zimmer
# 95826      2020-01-01       121  Saatlen         12  Kreis 12           3   3 Zimmer
# 95827      2020-01-01       121  Saatlen         12  Kreis 12           3   3 Zimmer
# 95828      2020-01-01       121  Saatlen         12  Kreis 12           3   3 Zimmer
#
#        MietwohnungSort MietwohnungLang  BauperiodeSort BauperiodeLang  EigGruSort  \
# 95824                0            Nein               2    1893 - 1930           4
# 95825                0            Nein               3    1931 - 1940           4
# 95826                0            Nein               4    1941 - 1950           4
# 95827                0            Nein               7    1971 - 1980           5
# 95828                0            Nein               9    1991 - 2000           5
#
#                  EigGruLang  AnzWhg  Wohnungsfl
# 95824   Natürliche Personen       1         100
# 95825   Natürliche Personen       2         178
# 95826   Natürliche Personen       3         225
# 95827  Im Stockwerkeigentum      12        1278
# 95828  Im Stockwerkeigentum       6         530

# %%
# df_statzonen = df_statzonen[(df_statzonen.knr>0) & (df_statzonen.qname!="Hirslanden")]

highlight = alt.selection(type='single', on='mouseover',
                          fields=['QuarLang'], nearest=True)
#x='date:StichtagDatJahr',
base = alt.Chart(mySelection).encode(
    x='EigGruLang',
    y='AnzWhg',
    color='QuarLang'
)

points = base.mark_circle().encode(
    opacity=alt.value(0)
).add_selection(
    highlight
).properties(
    width=700 , height=300
)
lines = base.mark_line().encode(
    size=alt.condition(~highlight, alt.value(1.5), alt.value(4))
).interactive()

points + lines
# Out:
# alt.LayerChart(...)

# %%
alt.Chart(mySelection).mark_circle(size=60).encode(
    x='QuarLang',
    y='EigGruLang',
    #color='AnzWhg',
    #color=alt.Color('AnzNat', scale=alt.Scale(scheme='dark2')),
    color=alt.Color('AnzWhg', scale=alt.Scale(scheme='greens')),
    tooltip=['QuarLang','StichtagDatJahr','EigGruLang','AnzWhg']
).interactive() # this makes the axes interactive: now you can zoom & pan
# Out:
# alt.Chart(...)

# %% [markdown]
# **Test: Choroplethenkarte**
# Importiere die Geodaten als GeoJSON

# %%
# Read abt. Geopandas https://geopandas.org/docs/user_guide/io.html
# Wenn die Daten lokal agelegt sind, dann kannst Du folgendes machen:
##input_stadtquartiere = r"//szh.loc/ssz/data/GIS/Daten/Vektor/_aktuell/stzh.adm_statistische_quartiere_map.json"
##df_stadtquartiere = gpd.read_file(input_stadtquartiere)
##df_stadtquartiere.head(2)
#df_stadtkreise.dtypes

geojson_url = "https://www.ogd.stadt-zuerich.ch/wfs/geoportal/Statistische_Quartiere?service=WFS&version=1.1.0&request=GetFeature&outputFormat=GeoJSON&typename=adm_statistische_quartiere_map"
df_adm_statistische_quartiere_map = gpd.read_file(geojson_url)

df_adm_statistische_quartiere_map.head(5)
# Out:
#                                  id    kname  knr  objectid objid       qname  qnr  \
# 0  adm_statistische_quartiere_map.1  Kreis 7    7         1    34  Hirslanden   73
# 1  adm_statistische_quartiere_map.2  Kreis 8    8         2    33     Weinegg   83
# 2  adm_statistische_quartiere_map.3  Kreis 8    8         3    32   Mühlebach   82
# 3  adm_statistische_quartiere_map.4  Kreis 8    8         4    31     Seefeld   81
# 4  adm_statistische_quartiere_map.7  Kreis 4    4         7    16        Werd   41
#
#                                             geometry
# 0  POLYGON ((8.55670 47.36406, 8.55682 47.36410, ...
# 1  POLYGON ((8.55670 47.36405, 8.55672 47.36403, ...
# 2  POLYGON ((8.55423 47.36456, 8.55426 47.36452, ...
# 3  POLYGON ((8.54795 47.36500, 8.54805 47.36489, ...
# 4  POLYGON ((8.53300 47.37394, 8.53299 47.37392, ...

# %% [markdown]
# Joine die importierten statistischen Daten des aktuellen Jahres zum Geodatensatz:
#
# *Siehe dazu Doku zu [Geopandas](https://geopandas.org/docs/user_guide/mergingdata.html)*

# %%
aktuellesJahr.head()
# Out:
#       StichtagDatJahr  QuarSort QuarLang  KreisSort KreisLang  ZimmerSort ZimmerLang  \
# 87833      2020-01-01        11  Rathaus          1   Kreis 1           1   1 Zimmer
# 87834      2020-01-01        11  Rathaus          1   Kreis 1           1   1 Zimmer
# 87835      2020-01-01        11  Rathaus          1   Kreis 1           1   1 Zimmer
# 87836      2020-01-01        11  Rathaus          1   Kreis 1           1   1 Zimmer
# 87837      2020-01-01        11  Rathaus          1   Kreis 1           1   1 Zimmer
#
#        MietwohnungSort MietwohnungLang  BauperiodeSort BauperiodeLang  EigGruSort  \
# 87833                0            Nein               1       Vor 1893           5
# 87834                0            Nein               7    1971 - 1980           5
# 87835                1              Ja               1       Vor 1893           1
# 87836                1              Ja               1       Vor 1893           3
# 87837                1              Ja               1       Vor 1893           4
#
#                    EigGruLang  AnzWhg  Wohnungsfl
# 87833    Im Stockwerkeigentum       2          64
# 87834    Im Stockwerkeigentum       7         175
# 87835        Öffentliche Hand     119        4355
# 87836  Übrige private Gesell.     114        3198
# 87837     Natürliche Personen     178        5688

# %%
stats_agg_quartiere=aktuellesJahr.groupby(['StichtagDatJahr', 'QuarSort'])['AnzWhg','Wohnungsfl'].sum()
#test = data2betested.groupby(['StichtagDatJahr', 'AlterV20Kurz'])[['AnzBestWir']].agg()
stats_agg_quartiere.head()
#test = data2betested.groupby(['StichtagDatJahr', 'AlterV20Kurz'])[['AnzBestWir']].agg()
# Out:
# <ipython-input-26-57dbec7afa28>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   stats_agg_quartiere=aktuellesJahr.groupby(['StichtagDatJahr', 'QuarSort'])['AnzWhg','Wohnungsfl'].sum()
#                           AnzWhg  Wohnungsfl
# StichtagDatJahr QuarSort
# 2020-01-01      11          2317      157636
#                 12           329       28251
#                 13           842       62751
#                 14           392       37195
#                 21          9951      822501

# %%
# Rename attribute stznr to StatZoneSort, so the IDs have the same name

stadtquartiere_shapes = df_adm_statistische_quartiere_map[['geometry', 'qnr', 'qname', 'knr']].rename(columns={'qnr': 'QuarSort'})

# Merge with `merge` method on shared variable (stznr und StatZoneSort):
stadtquartiere_shapes_joined = stadtquartiere_shapes.merge(stats_agg_quartiere, on='QuarSort')

stadtquartiere_shapes_joined.head(3)
# Out:
#                                             geometry  QuarSort       qname  knr  AnzWhg  \
# 0  POLYGON ((8.55670 47.36406, 8.55682 47.36410, ...        73  Hirslanden    7    4127
# 1  POLYGON ((8.55670 47.36405, 8.55672 47.36403, ...        83     Weinegg    8    2876
# 2  POLYGON ((8.55423 47.36456, 8.55426 47.36452, ...        82   Mühlebach    8    3926
#
#    Wohnungsfl
# 0      353229
# 1      251744
# 2      310479

# %%
# Plot by StatQuartiere

stadtquartiere_shapes_joined.plot(column='AnzWhg', cmap='viridis', scheme='natural_breaks', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html

stadtquartiere_shapes_joined.plot(column='Wohnungsfl', cmap='plasma', scheme='quantiles', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html
stadtquartiere_shapes_joined.plot(column='AnzWhg', cmap='cool', scheme='fisherjenks', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html
# Out:
# <AxesSubplot:>

# %% [raw]
# fig, ax = plt.subplots(1, 1)
#
# statzonen_shapes_aktJahr.plot(column='AnzWhg', ax=ax, legend=True, legend_kwds={'label': "Anzahl Personen",'orientation': "horizontal"})

# %% [markdown]
# Noch zu prüfen, folgendes schöne Beispiel: https://docs.bokeh.org/en/latest/docs/user_guide/interaction/legends.html
#
# Konkrete Beispiele von Bookeh in Jupyter NB: https://docs.bokeh.org/en/latest/docs/user_guide/jupyter.html

# %% [markdown]
# **Sharepoint als gecheckt markieren!**

# %% [markdown]
# Record auf Sharepoint: **[Link](http://kollaboration.intranet.stzh.ch/orga/ssz-produkte/Lists/SASA_Outputs/EditForm.aspx?ID=157&Source=%2Forga%2Fssz%2Dprodukte%2FLists%2FSASA%5FOutputs)**
