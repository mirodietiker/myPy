# %% [markdown]
# # Update Abstimmungsresultate
# Datum: 29.09.2021
#
# Immer nach den Abstimmungen werden die Abstimmungsresultate vom Datamanagement aufbereitet und auf der «[**Abstimmungs-Datenbank
# von Statistik Stadt Zürich**](http://sszsttprd/statisticstools/Modules/Abstimmungen/Intranet/)» verfügbar gemacht.
#
# Für OGD kann dann via Exportfunktion (Format Roh > Export) ein Excelfile exportiert und unter folgendem Pfad abgelegt werden:
# `\\szh.loc\ssz\applikationen\OGD\Daten\Quelldaten\SSZ\Politik\abstimmungen\__Modules_Abstimmungen_Export_AbstimmungenExport.xls`
#
# Damit das die Ressourcen des Datasets «[Abstimmungsresultate der Stadt Zürich, seit 1933](https://data.stadt-zuerich.ch/dataset/politik-abstimmungen-seit-1933)» **manuell** aktualisiert werden können, muss das exportierte Excel noch
#  - als **Csv** aufbereitet und
#  - das Attribut 'Abstimmungs_Datum' noch ins korrekte Datumsformat (**JJJJ-MM-TT / ISO 8601**) umgewandelt
#  werden.
#
# Früher wurden diese simplen Schritte im Libre Office (Open Office) gemacht. Nun sollen sie noch einfacher per Python gemacht werden.
#
#
#
# <!---
# Dieses Notebook verwendet als Vorlage die Webseite «[Kitas in Berlin - Jupyter Notebook](https://juanitorduz.github.io/kitas_berlin/)»
# ---!>

# %%
#%pip install geopandas fiona requests folium mplleaflet contextily

# %%
import numpy as np
import pandas as pd
import pandas as pd
import pivottablejs
from pivottablejs import pivot_ui

# %% [markdown]
# ## Zuletzt veröffentlichte Abstimmungsresultate
# Wie sehen die aktuell auf dem OGD-Katalog veröffentlichten Daten dazu aus?

# %%
url_abstimmungsresultate =r"https://data.stadt-zuerich.ch/dataset/politik-abstimmungen-seit-1933/download/abstimmungen_seit1933.csv"

# Read the data
bisherige_abstimmungsresultate = pd.read_csv(
    url_abstimmungsresultate, 
    sep=','    
    )
bisherige_abstimmungsresultate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9662 entries, 0 to 9661
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Abstimmungs_Datum      9662 non-null   object
#  1   Nr_Politische_Ebene    9662 non-null   int64
#  2   Name_Politische_Ebene  9662 non-null   object
#  3   Abstimmungs_Text       9662 non-null   object
#  4   Nr_Resultat_Gebiet     9662 non-null   int64
#  5   Name_Resultat_Gebiet   9662 non-null   object
#  6   Nr_Wahlkreis_StZH      5102 non-null   float64
#  7   Name_Wahlkreis_StZH    5102 non-null   object
#  8   Stimmberechtigt        6524 non-null   float64
#  9   Ja                     9662 non-null   int64
#  10  Nein                   9662 non-null   int64
#  11  Stimmbeteiligung (%)   9662 non-null   float64
#  12  Ja (%)                 9662 non-null   float64
#  13  Nein (%)               9662 non-null   float64
#  14  StaendeJa              380 non-null    object
#  15  StaendeNein            384 non-null    object
# dtypes: float64(5), int64(4), object(7)
# memory usage: 1.2+ MB

# %%
bisherige_abstimmungsresultate.head(2)
# Out:
#   Abstimmungs_Datum  Nr_Politische_Ebene Name_Politische_Ebene  \
# 0        2021-06-13                    3          Stadt Zürich
# 1        2021-06-13                    3          Stadt Zürich
#
#                     Abstimmungs_Text  Nr_Resultat_Gebiet Name_Resultat_Gebiet  \
# 0  Totalrevision der Gemeindeordnung                   3         Stadt Zürich
# 1  Totalrevision der Gemeindeordnung                   3         Stadt Zürich
#
#    Nr_Wahlkreis_StZH Name_Wahlkreis_StZH  Stimmberechtigt     Ja   Nein  \
# 0                NaN                 NaN         234017.0  93080  30620
# 1                2.0           Kreis 1+2          22896.0   9055   3204
#
#    Stimmbeteiligung (%)  Ja (%)  Nein (%) StaendeJa StaendeNein
# 0                  55.9    75.2      24.8       NaN         NaN
# 1                  56.6    73.9      26.1       NaN         NaN

# %% [markdown]
# ## Importiere die neusten Abstimmungsresultate zur Datenaufbereitung
#
# Wir importieren das von der Abstimmungsdatenbank exportierte Excelfile und bereiten es für die Veröffentlichung für OGD auf.

# %% [markdown]
# Link zu `read_excel()` in Pandas: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html
#
# `pandas.read_excel(io, sheet_name=0, header=0, names=None, index_col=None, usecols=None, squeeze=False, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=None, mangle_dupe_cols=True, storage_options=None)`

# %%
# Filepath
fp = r"\\szh.loc\ssz\applikationen\OGD\Daten\Quelldaten\SSZ\Politik\abstimmungen\__Modules_Abstimmungen_Export_AbstimmungenExport.xls"

# Read the data
imp_abstimmungsresultate = pd.read_excel(
    io = fp, 
    parse_dates=True,
    dtype={'Abstimmungs_Text': str}
    )

# %%
imp_abstimmungsresultate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9708 entries, 0 to 9707
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Abstimmungs_Datum      9708 non-null   datetime64[ns]
#  1   Nr_Politische_Ebene    9708 non-null   int64
#  2   Name_Politische_Ebene  9708 non-null   object
#  3   Abstimmungs_Text       9708 non-null   object
#  4   Nr_Resultat_Gebiet     9708 non-null   int64
#  5   Name_Resultat_Gebiet   9708 non-null   object
#  6   Nr_Wahlkreis_StZH      5140 non-null   float64
#  7   Name_Wahlkreis_StZH    5140 non-null   object
#  8   Stimmberechtigt        6573 non-null   float64
#  9   Ja                     9708 non-null   int64
#  10  Nein                   9708 non-null   int64
#  11  Stimmbeteiligung (%)   9708 non-null   float64
#  12  Ja (%)                 9708 non-null   float64
#  13  Nein (%)               9708 non-null   float64
#  14  StaendeJa              382 non-null    object
#  15  StaendeNein            386 non-null    object
# dtypes: datetime64[ns](1), float64(5), int64(4), object(6)
# memory usage: 1.2+ MB

# %%
#test = imp_abstimmungsresultate.query("Abstimmungs_Datum == '2011-11-27'")
#test.head(20)

# %% [markdown]
# ## Gibt es beim Import Probleme?
# Damit sauber exportiert werden kann, müssen die Daten auch sauber eingelesen werden. Wie können wir das aber testen?
#
# Was sind die unique values per feature

# %%
imp_abstimmungsresultate.apply(lambda x: x.unique().size, axis=0)
# Out:
# Abstimmungs_Datum         415
# Nr_Politische_Ebene         3
# Name_Politische_Ebene       3
# Abstimmungs_Text         2497
# Nr_Resultat_Gebiet          3
# Name_Resultat_Gebiet        3
# Nr_Wahlkreis_StZH          17
# Name_Wahlkreis_StZH        17
# Stimmberechtigt          1168
# Ja                       8551
# Nein                     8183
# Stimmbeteiligung (%)     1575
# Ja (%)                    851
# Nein (%)                  851
# StaendeJa                  94
# StaendeNein                89
# dtype: int64

# %% [markdown]
# ## Speichere die neuen Resultate in ein OGD-konformes CSV-File
#
# OGD-konform bedeutet:
# - **Datenformat**: `CSV`,
# - **Encoding**: in `UTF8`,
# - **Strings**: Zwischen Anführungszeichen `""`
# - **Separator**: ` , `
#
# Link zu `to_csv()` in Pandas: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html
#
# DataFrame.to_csv(path_or_buf=None, sep=',', na_rep='', float_format=None, columns=None, header=True, index=True, index_label=None, mode='w', encoding=None, compression='infer', quoting=None, quotechar='"', line_terminator=None, chunksize=None, date_format=None, doublequote=True, escapechar=None, decimal='.', errors='strict', storage_options=None)

# %%
export_path=r"\\szh.loc\ssz\applikationen\OGD\Daten\Quelldaten\SSZ\Politik\abstimmungen\abstimmungen_seit1933.csv"

imp_abstimmungsresultate.to_csv(
    export_path,
    encoding="UTF-8-sig",
    quotechar='"',
    quoting=2,
    index=False,
    date_format='%Y-%m-%d'
)
print('done')

# encoding="UTF-8",
#date_format='%Y-%m-%dT%H:%M:%SZ'
# Out:
# done

# %% [markdown]
# ## Testing
#
# Teste den import der eben exportierten Daten. Klappt alles wie gewollt?

# %%
# Read the data
checkNewCsv = pd.read_csv(
    export_path, 
    parse_dates=True,
    )

# %%
#checkNewCsv.info(2)

# %%
from pivottablejs import pivot_ui

pivot_ui(checkNewCsv)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
checkNewCsv.query("Abstimmungs_Datum == '2011-11-27' & Nr_Politische_Ebene==2")
# Out:
#      Abstimmungs_Datum  Nr_Politische_Ebene Name_Politische_Ebene  \
# 2968        2011-11-27                    2         Kanton Zürich
# 2969        2011-11-27                    2         Kanton Zürich
# 2970        2011-11-27                    2         Kanton Zürich
# 2971        2011-11-27                    2         Kanton Zürich
# 2972        2011-11-27                    2         Kanton Zürich
# 2973        2011-11-27                    2         Kanton Zürich
# 2974        2011-11-27                    2         Kanton Zürich
# 2975        2011-11-27                    2         Kanton Zürich
# 2976        2011-11-27                    2         Kanton Zürich
# 2977        2011-11-27                    2         Kanton Zürich
# 2978        2011-11-27                    2         Kanton Zürich
# 2979        2011-11-27                    2         Kanton Zürich
# 2980        2011-11-27                    2         Kanton Zürich
# 2981        2011-11-27                    2         Kanton Zürich
# 2982        2011-11-27                    2         Kanton Zürich
# 2983        2011-11-27                    2         Kanton Zürich
# 2984        2011-11-27                    2         Kanton Zürich
# 2985        2011-11-27                    2         Kanton Zürich
# 2986        2011-11-27                    2         Kanton Zürich
# 2987        2011-11-27                    2         Kanton Zürich
# 2988        2011-11-27                    2         Kanton Zürich
# 2989        2011-11-27                    2         Kanton Zürich
# 2990        2011-11-27                    2         Kanton Zürich
# 2991        2011-11-27                    2         Kanton Zürich
# 2992        2011-11-27                    2         Kanton Zürich
# 2993        2011-11-27                    2         Kanton Zürich
# 2994        2011-11-27                    2         Kanton Zürich
# 2995        2011-11-27                    2         Kanton Zürich
# 2996        2011-11-27                    2         Kanton Zürich
# 2997        2011-11-27                    2         Kanton Zürich
# 2998        2011-11-27                    2         Kanton Zürich
# 2999        2011-11-27                    2         Kanton Zürich
# 3000        2011-11-27                    2         Kanton Zürich
# 3001        2011-11-27                    2         Kanton Zürich
# 3002        2011-11-27                    2         Kanton Zürich
# 3003        2011-11-27                    2         Kanton Zürich
# 3004        2011-11-27                    2         Kanton Zürich
# 3005        2011-11-27                    2         Kanton Zürich
# 3006        2011-11-27                    2         Kanton Zürich
# 3007        2011-11-27                    2         Kanton Zürich
# 3008        2011-11-27                    2         Kanton Zürich
# 3009        2011-11-27                    2         Kanton Zürich
# 3010        2011-11-27                    2         Kanton Zürich
# 3011        2011-11-27                    2         Kanton Zürich
# 3012        2011-11-27                    2         Kanton Zürich
# 3013        2011-11-27                    2         Kanton Zürich
# 3014        2011-11-27                    2         Kanton Zürich
# 3015        2011-11-27                    2         Kanton Zürich
# 3016        2011-11-27                    2         Kanton Zürich
# 3017        2011-11-27                    2         Kanton Zürich
# 3018        2011-11-27                    2         Kanton Zürich
# 3019        2011-11-27                    2         Kanton Zürich
# 3020        2011-11-27                    2         Kanton Zürich
# 3021        2011-11-27                    2         Kanton Zürich
# 3022        2011-11-27                    2         Kanton Zürich
#
#                                        Abstimmungs_Text  Nr_Resultat_Gebiet  \
# 2968  A. Gesetz über den Flughafen Zürich (Flughafen...                   2
# 2969  A. Gesetz über den Flughafen Zürich (Flughafen...                   3
# 2970  A. Gesetz über den Flughafen Zürich (Flughafen...                   3
# 2971  A. Gesetz über den Flughafen Zürich (Flughafen...                   3
# 2972  A. Gesetz über den Flughafen Zürich (Flughafen...                   3
# 2973  A. Gesetz über den Flughafen Zürich (Flughafen...                   3
# 2974  A. Gesetz über den Flughafen Zürich (Flughafen...                   3
# 2975  A. Gesetz über den Flughafen Zürich (Flughafen...                   3
# 2976  A. Gesetz über den Flughafen Zürich (Flughafen...                   3
# 2977  A. Gesetz über den Flughafen Zürich (Flughafen...                   3
# 2978  A. Gesetz über den Flughafen Zürich (Flughafen...                   3
# 2979  B. Gültige Teile des Gegenvorschlags von Stimm...                   2
# 2980  B. Gültige Teile des Gegenvorschlags von Stimm...                   3
# 2981  B. Gültige Teile des Gegenvorschlags von Stimm...                   3
# 2982  B. Gültige Teile des Gegenvorschlags von Stimm...                   3
# 2983  B. Gültige Teile des Gegenvorschlags von Stimm...                   3
# 2984  B. Gültige Teile des Gegenvorschlags von Stimm...                   3
# 2985  B. Gültige Teile des Gegenvorschlags von Stimm...                   3
# 2986  B. Gültige Teile des Gegenvorschlags von Stimm...                   3
# 2987  B. Gültige Teile des Gegenvorschlags von Stimm...                   3
# 2988  B. Gültige Teile des Gegenvorschlags von Stimm...                   3
# 2989  B. Gültige Teile des Gegenvorschlags von Stimm...                   3
# 2990  C. Stichfrage: Welche der beiden Vorlagen soll...                   2
# 2991  C. Stichfrage: Welche der beiden Vorlagen soll...                   3
# 2992  C. Stichfrage: Welche der beiden Vorlagen soll...                   3
# 2993  C. Stichfrage: Welche der beiden Vorlagen soll...                   3
# 2994  C. Stichfrage: Welche der beiden Vorlagen soll...                   3
# 2995  C. Stichfrage: Welche der beiden Vorlagen soll...                   3
# 2996  C. Stichfrage: Welche der beiden Vorlagen soll...                   3
# 2997  C. Stichfrage: Welche der beiden Vorlagen soll...                   3
# 2998  C. Stichfrage: Welche der beiden Vorlagen soll...                   3
# 2999  C. Stichfrage: Welche der beiden Vorlagen soll...                   3
# 3000  C. Stichfrage: Welche der beiden Vorlagen soll...                   3
# 3001  «Stau weg!» - Kantonale Volksinitiative zur Ei...                   2
# 3002  «Stau weg!» - Kantonale Volksinitiative zur Ei...                   3
# 3003  «Stau weg!» - Kantonale Volksinitiative zur Ei...                   3
# 3004  «Stau weg!» - Kantonale Volksinitiative zur Ei...                   3
# 3005  «Stau weg!» - Kantonale Volksinitiative zur Ei...                   3
# 3006  «Stau weg!» - Kantonale Volksinitiative zur Ei...                   3
# 3007  «Stau weg!» - Kantonale Volksinitiative zur Ei...                   3
# 3008  «Stau weg!» - Kantonale Volksinitiative zur Ei...                   3
# 3009  «Stau weg!» - Kantonale Volksinitiative zur Ei...                   3
# 3010  «Stau weg!» - Kantonale Volksinitiative zur Ei...                   3
# 3011  «Stau weg!» - Kantonale Volksinitiative zur Ei...                   3
# 3012      Kantonale Volksinitiative «Für faire Ferien».                   2
# 3013      Kantonale Volksinitiative «Für faire Ferien».                   3
# 3014      Kantonale Volksinitiative «Für faire Ferien».                   3
# 3015      Kantonale Volksinitiative «Für faire Ferien».                   3
# 3016      Kantonale Volksinitiative «Für faire Ferien».                   3
# 3017      Kantonale Volksinitiative «Für faire Ferien».                   3
# 3018      Kantonale Volksinitiative «Für faire Ferien».                   3
# 3019      Kantonale Volksinitiative «Für faire Ferien».                   3
# 3020      Kantonale Volksinitiative «Für faire Ferien».                   3
# 3021      Kantonale Volksinitiative «Für faire Ferien».                   3
# 3022      Kantonale Volksinitiative «Für faire Ferien».                   3
#
#      Name_Resultat_Gebiet  Nr_Wahlkreis_StZH Name_Wahlkreis_StZH  \
# 2968        Kanton Zürich                NaN                 NaN
# 2969         Stadt Zürich                NaN                 NaN
# 2970         Stadt Zürich                2.0           Kreis 1+2
# 2971         Stadt Zürich                3.0             Kreis 3
# 2972         Stadt Zürich                4.0           Kreis 4+5
# 2973         Stadt Zürich                5.0             Kreis 6
# 2974         Stadt Zürich                6.0           Kreis 7+8
# 2975         Stadt Zürich                7.0             Kreis 9
# 2976         Stadt Zürich                8.0            Kreis 10
# 2977         Stadt Zürich                9.0            Kreis 11
# 2978         Stadt Zürich               10.0            Kreis 12
# 2979        Kanton Zürich                NaN                 NaN
# 2980         Stadt Zürich                NaN                 NaN
# 2981         Stadt Zürich                2.0           Kreis 1+2
# 2982         Stadt Zürich                3.0             Kreis 3
# 2983         Stadt Zürich                4.0           Kreis 4+5
# 2984         Stadt Zürich                5.0             Kreis 6
# 2985         Stadt Zürich                6.0           Kreis 7+8
# 2986         Stadt Zürich                7.0             Kreis 9
# 2987         Stadt Zürich                8.0            Kreis 10
# 2988         Stadt Zürich                9.0            Kreis 11
# 2989         Stadt Zürich               10.0            Kreis 12
# 2990        Kanton Zürich                NaN                 NaN
# 2991         Stadt Zürich                NaN                 NaN
# 2992         Stadt Zürich                2.0           Kreis 1+2
# 2993         Stadt Zürich                3.0             Kreis 3
# 2994         Stadt Zürich                4.0           Kreis 4+5
# 2995         Stadt Zürich                5.0             Kreis 6
# 2996         Stadt Zürich                6.0           Kreis 7+8
# 2997         Stadt Zürich                7.0             Kreis 9
# 2998         Stadt Zürich                8.0            Kreis 10
# 2999         Stadt Zürich                9.0            Kreis 11
# 3000         Stadt Zürich               10.0            Kreis 12
# 3001        Kanton Zürich                NaN                 NaN
# 3002         Stadt Zürich                NaN                 NaN
# 3003         Stadt Zürich                2.0           Kreis 1+2
# 3004         Stadt Zürich                3.0             Kreis 3
# 3005         Stadt Zürich                4.0           Kreis 4+5
# 3006         Stadt Zürich                5.0             Kreis 6
# 3007         Stadt Zürich                6.0           Kreis 7+8
# 3008         Stadt Zürich                7.0             Kreis 9
# 3009         Stadt Zürich                8.0            Kreis 10
# 3010         Stadt Zürich                9.0            Kreis 11
# 3011         Stadt Zürich               10.0            Kreis 12
# 3012        Kanton Zürich                NaN                 NaN
# 3013         Stadt Zürich                NaN                 NaN
# 3014         Stadt Zürich                2.0           Kreis 1+2
# 3015         Stadt Zürich                3.0             Kreis 3
# 3016         Stadt Zürich                4.0           Kreis 4+5
# 3017         Stadt Zürich                5.0             Kreis 6
# 3018         Stadt Zürich                6.0           Kreis 7+8
# 3019         Stadt Zürich                7.0             Kreis 9
# 3020         Stadt Zürich                8.0            Kreis 10
# 3021         Stadt Zürich                9.0            Kreis 11
# 3022         Stadt Zürich               10.0            Kreis 12
#
#       Stimmberechtigt      Ja    Nein  Stimmbeteiligung (%)  Ja (%)  Nein (%)  \
# 2968         859238.0  150750  214995                 44.14    41.2      58.8
# 2969         219343.0   35801   51720                 42.07    40.9      59.1
# 2970          22073.0    3497    5515                 43.09    38.8      61.2
# 2971          26562.0    4340    5642                 39.87    43.5      56.5
# 2972          21208.0    3155    3988                 36.05    44.2      55.8
# 2973          18228.0    3549    4852                 48.97    42.2      57.8
# 2974          30578.0    5303    9509                 51.01    35.8      64.2
# 2975          28240.0    4018    6187                 38.08    39.4      60.6
# 2976          23145.0    4458    6124                 48.02    42.1      57.9
# 2977          34832.0    5280    7503                 38.32    41.3      58.7
# 2978          14477.0    2201    2400                 33.07    47.8      52.2
# 2979         859238.0  109411  235021                 44.14    31.8      68.2
# 2980         219343.0   26594   54863                 42.07    32.6      67.4
# 2981          22073.0    2431    5959                 43.09    29.0      71.0
# 2982          26562.0    3159    6108                 39.87    34.1      65.9
# 2983          21208.0    2456    4274                 36.05    36.5      63.5
# 2984          18228.0    2542    5297                 48.97    32.4      67.6
# 2985          30578.0    4239    9600                 51.01    30.6      69.4
# 2986          28240.0    2911    6432                 38.08    31.2      68.8
# 2987          23145.0    3165    6709                 48.02    32.1      67.9
# 2988          34832.0    3829    8111                 38.32    32.1      67.9
# 2989          14477.0    1862    2373                 33.07    44.0      56.0
# 2990         859238.0  206373   75611                 44.14    73.2      26.8
# 2991         219343.0   46420   21739                 42.07    68.1      31.9
# 2992          22073.0    4880    2090                 43.09    70.0      30.0
# 2993          26562.0    5209    2546                 39.87    67.2      32.8
# 2994          21208.0    3958    1861                 36.05    68.0      32.0
# 2995          18228.0    4780    2000                 48.97    70.5      29.5
# 2996          30578.0    7581    4021                 51.01    65.3      34.7
# 2997          28240.0    5336    2303                 38.08    69.9      30.1
# 2998          23145.0    5818    2493                 48.02    70.0      30.0
# 2999          34832.0    6729    3042                 38.32    68.9      31.1
# 3000          14477.0    2129    1383                 33.07    60.6      39.4
# 3001         859238.0  135632  229972                 44.11    37.1      62.9
# 3002         219343.0   27021   62412                 42.56    30.2      69.8
# 3003          22073.0    2805    6439                 43.83    30.3      69.7
# 3004          26562.0    2716    7615                 40.67    26.3      73.7
# 3005          21208.0    1705    5828                 37.08    22.6      77.4
# 3006          18228.0    2111    6499                 49.43    24.5      75.5
# 3007          30578.0    4162   10835                 51.20    27.8      72.2
# 3008          28240.0    3790    6675                 38.70    36.2      63.8
# 3009          23145.0    3167    7680                 48.71    29.2      70.8
# 3010          34832.0    4618    8252                 38.42    35.9      64.1
# 3011          14477.0    1947    2589                 32.86    42.9      57.1
# 3012         859238.0  140682  226273                 44.24    38.3      61.7
# 3013         219343.0   42789   46933                 42.74    47.7      52.3
# 3014          22073.0    4063    5232                 44.04    43.7      56.3
# 3015          26562.0    5601    4762                 40.85    54.0      46.0
# 3016          21208.0    4482    3078                 37.30    59.3      40.7
# 3017          18228.0    4239    4367                 49.53    49.3      50.7
# 3018          30578.0    5911    9155                 51.52    39.2      60.8
# 3019          28240.0    4961    5573                 38.90    47.1      52.9
# 3020          23145.0    5131    5745                 48.93    47.2      52.8
# 3021          34832.0    6107    6790                 38.50    47.4      52.6
# 3022          14477.0    2294    2231                 32.84    50.7      49.3
#
#      StaendeJa StaendeNein
# 2968       NaN         NaN
# 2969       NaN         NaN
# 2970       NaN         NaN
# 2971       NaN         NaN
# 2972       NaN         NaN
# 2973       NaN         NaN
# 2974       NaN         NaN
# 2975       NaN         NaN
# 2976       NaN         NaN
# 2977       NaN         NaN
# 2978       NaN         NaN
# 2979       NaN         NaN
# 2980       NaN         NaN
# 2981       NaN         NaN
# 2982       NaN         NaN
# 2983       NaN         NaN
# 2984       NaN         NaN
# 2985       NaN         NaN
# 2986       NaN         NaN
# 2987       NaN         NaN
# 2988       NaN         NaN
# 2989       NaN         NaN
# 2990       NaN         NaN
# 2991       NaN         NaN
# 2992       NaN         NaN
# 2993       NaN         NaN
# 2994       NaN         NaN
# 2995       NaN         NaN
# 2996       NaN         NaN
# 2997       NaN         NaN
# 2998       NaN         NaN
# 2999       NaN         NaN
# 3000       NaN         NaN
# 3001       NaN         NaN
# 3002       NaN         NaN
# 3003       NaN         NaN
# 3004       NaN         NaN
# 3005       NaN         NaN
# 3006       NaN         NaN
# 3007       NaN         NaN
# 3008       NaN         NaN
# 3009       NaN         NaN
# 3010       NaN         NaN
# 3011       NaN         NaN
# 3012       NaN         NaN
# 3013       NaN         NaN
# 3014       NaN         NaN
# 3015       NaN         NaN
# 3016       NaN         NaN
# 3017       NaN         NaN
# 3018       NaN         NaN
# 3019       NaN         NaN
# 3020       NaN         NaN
# 3021       NaN         NaN
# 3022       NaN         NaN
